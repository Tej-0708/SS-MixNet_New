# %%
# !pip install spectral tqdm scikit-learn

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Collecting spectral
#   Downloading spectral-0.24-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from spectral) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Downloading spectral-0.24-py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.0/249.0 kB 18.5 MB/s eta 0:00:00
# Installing collected packages: spectral
# Successfully installed spectral-0.24
# Mounted at /content/drive

# %%
import os
import numpy as np
import tensorflow as tf
from scipy.io import loadmat
from tqdm import tqdm
import matplotlib.pyplot as plt
import spectral

from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import minmax_scale
from sklearn.metrics import accuracy_score, confusion_matrix, cohen_kappa_score

from tensorflow.keras.layers import (
    Input, Conv3D, Conv2D, Dense, Dropout, Reshape,
    Concatenate, Add, GlobalAveragePooling2D,
    Permute, Multiply, Conv1D
)
from tensorflow.keras.models import Model

# %%
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

print("Mixed precision policy:", mixed_precision.global_policy())
# Out:
# Mixed precision policy: <DTypePolicy "mixed_float16">

# %%
def loadData(name):

    data_path = '/content/drive/MyDrive/datasets'

    if name == 'Tangdaowan':
        data = loadmat(os.path.join(data_path, 'QUH-Tangdaowan.mat'))['Tangdaowan']
        labels = loadmat(os.path.join(data_path, 'QUH-Tangdaowan_GT.mat'))['TangdaowanGT']
        class_name = [
            "Rubber track","Flaggingv","Sandy","Asphalt","Boardwalk",
            "Rocky shallows","Grassland","Bulrush","Gravel road",
            "Ligustrum vicaryi","Coniferous pine","Spiraea","Bare soil",
            "Buxus sinica","Photinia serrulata","Populus",
            "Ulmus pumila L","Seawater"
        ]

    elif name == 'Qingyun':
        data = loadmat(os.path.join(data_path, 'QUH-Qingyun.mat'))['Chengqu']
        labels = loadmat(os.path.join(data_path, 'QUH-Qingyun_GT.mat'))['ChengquGT']
        class_name = [
            "Trees","Concrete building","Car",
            "Ironhide building","Plastic playground","Asphalt road"
        ]

    elif name == 'Pingan':
        data = loadmat(os.path.join(data_path, 'QUH-Pingan.mat'))['Haigang']
        labels = loadmat(os.path.join(data_path, 'QUH-Pingan_GT.mat'))['HaigangGT']
        class_name = [
            "Ship","Seawater","Trees","Concrete structure building",
            "Floating pier","Asphalt road","Brick houses",
            "Steel houses","Wharf construction land","Car","Road"
        ]

    return data, labels, class_name

# %%
def applyPCA(X, numComponents=15):

    newX = np.reshape(X, (-1, X.shape[2]))

    pca = PCA(n_components=numComponents)
    newX = pca.fit_transform(newX)

    newX = minmax_scale(newX, axis=1)

    newX = np.reshape(newX, (X.shape[0], X.shape[1], numComponents))

    return newX

# %%
def createImageCubes(X, indices, windowSize):

    margin = windowSize // 2
    N, M, P = X.shape

    X_padded = np.zeros((N+2*margin, M+2*margin, P))
    X_padded[margin:N+margin, margin:M+margin, :] = X

    patches = []

    for idx in indices:
        i,j = idx
        i += margin
        j += margin

        patch = X_padded[i-margin:i+margin+1, j-margin:j+margin+1, :]
        patches.append(patch)

    patches = np.array(patches)
    patches = patches[..., np.newaxis]  # needed for Conv3D

    return patches

# %%
def get_img_indexes(class_map, removeZeroindexes=True):

    if removeZeroindexes:
        indices = np.argwhere(class_map != 0)
    else:
        indices = np.argwhere(class_map != None)

    labels = class_map[indices[:,0], indices[:,1]]
    indices = [tuple(i) for i in indices]

    return indices, np.array(labels.tolist())-1

# %%
def splitTrainTestSet(X, y, testRatio):

    return train_test_split(
        X,
        y,
        test_size=testRatio,
        stratify=y,
        random_state=42
    )

# %%
def spectral_mixer_block(x, hidden_dim, num_blocks=2):

    H,W,C,D = x.shape[1:]

    x = Permute((1,2,4,3))(x)
    x = Reshape((H*W, D, C))(x)

    for _ in range(num_blocks):
        x1 = Dense(hidden_dim, activation='gelu')(x)
        x1 = Dense(C)(x1)
        x = Add()([x,x1])

    return Reshape((H,W,C,D))(x)

# %%
def spatial_mixer_block(x, hidden_dim, num_blocks=2):

    H,W,C,D = x.shape[1:]

    x = Permute((3,4,1,2))(x)
    x = Reshape((C,D,H*W))(x)

    for _ in range(num_blocks):
        x1 = Dense(hidden_dim, activation='gelu')(x)
        x1 = Dense(H*W)(x1)
        x = Add()([x,x1])

    x = Permute((3,1,2))(x)

    return Reshape((H,W,C,D))(x)

# %%
def eca_block(x, k_size=3):

    channels = x.shape[-1]

    y = GlobalAveragePooling2D()(x)
    y = Reshape((channels,1))(y)

    y = Conv1D(1, kernel_size=k_size, padding='same', use_bias=False)(y)
    y = tf.keras.activations.sigmoid(y)

    y = Reshape((1,1,channels))(y)

    return Multiply()([x,y])

# %%
def SS_MixNet(img_list, num_classes, mixer_dim=256):

    input_shape = img_list.shape[1:]
    inp = Input(shape=input_shape)

    x = Conv3D(32,(3,3,3),padding='same',activation='gelu')(inp)
    x = Conv3D(64,(3,3,3),padding='same',activation='gelu')(x)

    x_spe = spectral_mixer_block(x,mixer_dim)
    x_spa = spatial_mixer_block(x,mixer_dim)

    x = Concatenate(axis=4)([x_spe,x_spa])

    H,W,C,F = x.shape[1:]
    x = Reshape((H,W,C*F))(x)

    x = eca_block(x)

    res = Conv2D(x.shape[-1],1,padding='same',activation='gelu')(x)
    x = Add()([x,res])

    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.4)(x)

    out = Dense(num_classes,activation='softmax',dtype='float32')(x)

    model = Model(inp,out)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
        metrics=['accuracy']
    )

    return model

# %%
DATASET='Tangdaowan'

data,gt,class_name = loadData(DATASET)

print("Data shape:",data.shape)
# Out:
# Data shape: (1740, 860, 176)

# %%
data = applyPCA(data, numComponents=15)

# %%
indexes,labels = get_img_indexes(gt)

X_train_idx,X_test_idx,y_train,y_test = splitTrainTestSet(indexes,labels,0.95)
X_train_idx,X_val_idx,y_train,y_val = splitTrainTestSet(X_train_idx,y_train,0.30)

# %%
window_size=9

X_train=createImageCubes(data,X_train_idx,window_size)
X_val=createImageCubes(data,X_val_idx,window_size)

y_train=tf.keras.utils.to_categorical(y_train)
y_val=tf.keras.utils.to_categorical(y_val)

# %%
model = SS_MixNet(
    X_train,
    num_classes=len(class_name),
    mixer_dim=256
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 9, 9, 15,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d (Conv3D)     │ (None, 9, 9, 15,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_1 (Conv3D)   │ (None, 9, 9, 15,  │     55,360 │ conv3d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_1 (Permute) │ (None, 15, 64, 9, │          0 │ conv3d_1[0][0]    │
# │                     │ 9)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute (Permute)   │ (None, 9, 9, 64,  │          0 │ conv3d_1[0][0]    │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 15, 64,    │          0 │ permute_1[0][0]   │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 81, 64,    │          0 │ permute[0][0]     │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 15, 64,    │     20,992 │ reshape_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 81, 64,    │      4,096 │ reshape[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 15, 64,    │     20,817 │ dense_4[0][0]     │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 81, 64,    │      3,855 │ dense[0][0]       │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 15, 64,    │          0 │ reshape_2[0][0],  │
# │                     │ 81)               │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 81, 64,    │          0 │ reshape[0][0],    │
# │                     │ 15)               │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 15, 64,    │     20,992 │ add_2[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 81, 64,    │      4,096 │ add[0][0]         │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 15, 64,    │     20,817 │ dense_6[0][0]     │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 81, 64,    │      3,855 │ dense_2[0][0]     │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 15, 64,    │          0 │ add_2[0][0],      │
# │                     │ 81)               │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 81, 64,    │          0 │ add[0][0],        │
# │                     │ 15)               │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_2 (Permute) │ (None, 81, 15,    │          0 │ add_3[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 9, 9, 15,  │          0 │ add_1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 9, 9, 15,  │          0 │ permute_2[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 9, 9, 15,  │          0 │ reshape_1[0][0],  │
# │ (Concatenate)       │ 128)              │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 9, 9,      │          0 │ concatenate[0][0] │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1920)      │          0 │ reshape_4[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_5 (Reshape) │ (None, 1920, 1)   │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 1920, 1)   │          3 │ reshape_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sigmoid (Sigmoid)   │ (None, 1920, 1)   │          0 │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_6 (Reshape) │ (None, 1, 1,      │          0 │ sigmoid[0][0]     │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 9, 9,      │          0 │ reshape_4[0][0],  │
# │                     │ 1920)             │            │ reshape_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 9, 9,      │  3,688,320 │ multiply[0][0]    │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 9, 9,      │          0 │ multiply[0][0],   │
# │                     │ 1920)             │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1920)      │          0 │ add_4[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1920)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 18)        │     34,578 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,878,677 (14.80 MB)
#  Trainable params: 3,878,677 (14.80 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
checkpoint=tf.keras.callbacks.ModelCheckpoint(
    f"{DATASET}_SS_MixNet.keras",
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

lr_callback=tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=8,
    min_lr=5e-5
)

early_stop=tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=12,
    restore_best_weights=True
)

history=model.fit(
    X_train,
    y_train,
    epochs=60,
    batch_size=256,
    validation_data=(X_val,y_val),
    callbacks=[checkpoint,lr_callback,early_stop]
)
# Out:
# Epoch 1/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.4127 - loss: 2.1652
# Epoch 1: val_accuracy improved from -inf to 0.73592, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 75s 518ms/step - accuracy: 0.4143 - loss: 2.1598 - val_accuracy: 0.7359 - val_loss: 1.1721 - learning_rate: 3.0000e-04
# Epoch 2/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.7376 - loss: 1.0841
# Epoch 2: val_accuracy improved from 0.73592 to 0.82418, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 215ms/step - accuracy: 0.7382 - loss: 1.0819 - val_accuracy: 0.8242 - val_loss: 0.8542 - learning_rate: 3.0000e-04
# Epoch 3/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8194 - loss: 0.8306
# Epoch 3: val_accuracy improved from 0.82418 to 0.86174, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 217ms/step - accuracy: 0.8197 - loss: 0.8300 - val_accuracy: 0.8617 - val_loss: 0.7174 - learning_rate: 3.0000e-04
# Epoch 4/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.8609 - loss: 0.7186
# Epoch 4: val_accuracy improved from 0.86174 to 0.90145, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 218ms/step - accuracy: 0.8611 - loss: 0.7179 - val_accuracy: 0.9014 - val_loss: 0.6176 - learning_rate: 3.0000e-04
# Epoch 5/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9046 - loss: 0.6164
# Epoch 5: val_accuracy improved from 0.90145 to 0.91209, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 216ms/step - accuracy: 0.9046 - loss: 0.6161 - val_accuracy: 0.9121 - val_loss: 0.5635 - learning_rate: 3.0000e-04
# Epoch 6/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9212 - loss: 0.5629
# Epoch 6: val_accuracy improved from 0.91209 to 0.93709, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - accuracy: 0.9213 - loss: 0.5626 - val_accuracy: 0.9371 - val_loss: 0.5186 - learning_rate: 3.0000e-04
# Epoch 7/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9293 - loss: 0.5311
# Epoch 7: val_accuracy improved from 0.93709 to 0.94295, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - accuracy: 0.9295 - loss: 0.5308 - val_accuracy: 0.9429 - val_loss: 0.4955 - learning_rate: 3.0000e-04
# Epoch 8/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9456 - loss: 0.4929
# Epoch 8: val_accuracy improved from 0.94295 to 0.95192, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 215ms/step - accuracy: 0.9456 - loss: 0.4929 - val_accuracy: 0.9519 - val_loss: 0.4731 - learning_rate: 3.0000e-04
# Epoch 9/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9535 - loss: 0.4778
# Epoch 9: val_accuracy improved from 0.95192 to 0.95407, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 215ms/step - accuracy: 0.9535 - loss: 0.4778 - val_accuracy: 0.9541 - val_loss: 0.4667 - learning_rate: 3.0000e-04
# Epoch 10/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9572 - loss: 0.4659
# Epoch 10: val_accuracy did not improve from 0.95407
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 210ms/step - accuracy: 0.9571 - loss: 0.4658 - val_accuracy: 0.9538 - val_loss: 0.4575 - learning_rate: 3.0000e-04
# Epoch 11/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9604 - loss: 0.4554
# Epoch 11: val_accuracy improved from 0.95407 to 0.95826, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 218ms/step - accuracy: 0.9604 - loss: 0.4554 - val_accuracy: 0.9583 - val_loss: 0.4481 - learning_rate: 3.0000e-04
# Epoch 12/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9649 - loss: 0.4442
# Epoch 12: val_accuracy improved from 0.95826 to 0.96400, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.9649 - loss: 0.4441 - val_accuracy: 0.9640 - val_loss: 0.4402 - learning_rate: 3.0000e-04
# Epoch 13/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9677 - loss: 0.4392
# Epoch 13: val_accuracy did not improve from 0.96400
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.9677 - loss: 0.4390 - val_accuracy: 0.9603 - val_loss: 0.4402 - learning_rate: 3.0000e-04
# Epoch 14/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9695 - loss: 0.4299
# Epoch 14: val_accuracy did not improve from 0.96400
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9695 - loss: 0.4298 - val_accuracy: 0.9584 - val_loss: 0.4385 - learning_rate: 3.0000e-04
# Epoch 15/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9724 - loss: 0.4200
# Epoch 15: val_accuracy improved from 0.96400 to 0.96448, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 215ms/step - accuracy: 0.9724 - loss: 0.4200 - val_accuracy: 0.9645 - val_loss: 0.4255 - learning_rate: 3.0000e-04
# Epoch 16/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9753 - loss: 0.4129
# Epoch 16: val_accuracy improved from 0.96448 to 0.96687, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 215ms/step - accuracy: 0.9752 - loss: 0.4130 - val_accuracy: 0.9669 - val_loss: 0.4260 - learning_rate: 3.0000e-04
# Epoch 17/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9764 - loss: 0.4129
# Epoch 17: val_accuracy improved from 0.96687 to 0.96986, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - accuracy: 0.9765 - loss: 0.4129 - val_accuracy: 0.9699 - val_loss: 0.4209 - learning_rate: 3.0000e-04
# Epoch 18/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9772 - loss: 0.4098
# Epoch 18: val_accuracy improved from 0.96986 to 0.97333, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.9772 - loss: 0.4098 - val_accuracy: 0.9733 - val_loss: 0.4124 - learning_rate: 3.0000e-04
# Epoch 19/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9829 - loss: 0.3972
# Epoch 19: val_accuracy did not improve from 0.97333
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 208ms/step - accuracy: 0.9829 - loss: 0.3972 - val_accuracy: 0.9731 - val_loss: 0.4088 - learning_rate: 3.0000e-04
# Epoch 20/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9823 - loss: 0.3962
# Epoch 20: val_accuracy improved from 0.97333 to 0.97476, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 216ms/step - accuracy: 0.9823 - loss: 0.3961 - val_accuracy: 0.9748 - val_loss: 0.4065 - learning_rate: 3.0000e-04
# Epoch 21/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9815 - loss: 0.3970
# Epoch 21: val_accuracy did not improve from 0.97476
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.9816 - loss: 0.3969 - val_accuracy: 0.9720 - val_loss: 0.4102 - learning_rate: 3.0000e-04
# Epoch 22/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9845 - loss: 0.3886
# Epoch 22: val_accuracy improved from 0.97476 to 0.97680, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - accuracy: 0.9846 - loss: 0.3886 - val_accuracy: 0.9768 - val_loss: 0.4027 - learning_rate: 3.0000e-04
# Epoch 23/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9860 - loss: 0.3831
# Epoch 23: val_accuracy did not improve from 0.97680
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9860 - loss: 0.3831 - val_accuracy: 0.9750 - val_loss: 0.4032 - learning_rate: 3.0000e-04
# Epoch 24/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9860 - loss: 0.3846
# Epoch 24: val_accuracy did not improve from 0.97680
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9860 - loss: 0.3846 - val_accuracy: 0.9763 - val_loss: 0.3995 - learning_rate: 3.0000e-04
# Epoch 25/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9881 - loss: 0.3795
# Epoch 25: val_accuracy improved from 0.97680 to 0.97799, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 215ms/step - accuracy: 0.9881 - loss: 0.3795 - val_accuracy: 0.9780 - val_loss: 0.3975 - learning_rate: 3.0000e-04
# Epoch 26/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9894 - loss: 0.3767
# Epoch 26: val_accuracy improved from 0.97799 to 0.97871, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 221ms/step - accuracy: 0.9894 - loss: 0.3767 - val_accuracy: 0.9787 - val_loss: 0.3960 - learning_rate: 3.0000e-04
# Epoch 27/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9899 - loss: 0.3748
# Epoch 27: val_accuracy did not improve from 0.97871
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9898 - loss: 0.3748 - val_accuracy: 0.9763 - val_loss: 0.3978 - learning_rate: 3.0000e-04
# Epoch 28/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9916 - loss: 0.3717
# Epoch 28: val_accuracy did not improve from 0.97871
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.9916 - loss: 0.3718 - val_accuracy: 0.9779 - val_loss: 0.3966 - learning_rate: 3.0000e-04
# Epoch 29/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9902 - loss: 0.3741
# Epoch 29: val_accuracy did not improve from 0.97871
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9902 - loss: 0.3741 - val_accuracy: 0.9780 - val_loss: 0.3980 - learning_rate: 3.0000e-04
# Epoch 30/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9898 - loss: 0.3730
# Epoch 30: val_accuracy did not improve from 0.97871
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9898 - loss: 0.3730 - val_accuracy: 0.9774 - val_loss: 0.3977 - learning_rate: 3.0000e-04
# Epoch 31/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9915 - loss: 0.3724
# Epoch 31: val_accuracy improved from 0.97871 to 0.97967, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.9915 - loss: 0.3723 - val_accuracy: 0.9797 - val_loss: 0.3908 - learning_rate: 3.0000e-04
# Epoch 32/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9935 - loss: 0.3649
# Epoch 32: val_accuracy improved from 0.97967 to 0.98086, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 216ms/step - accuracy: 0.9935 - loss: 0.3649 - val_accuracy: 0.9809 - val_loss: 0.3873 - learning_rate: 3.0000e-04
# Epoch 33/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9946 - loss: 0.3632
# Epoch 33: val_accuracy did not improve from 0.98086
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.9946 - loss: 0.3632 - val_accuracy: 0.9793 - val_loss: 0.3938 - learning_rate: 3.0000e-04
# Epoch 34/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9929 - loss: 0.3639
# Epoch 34: val_accuracy improved from 0.98086 to 0.98170, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.9930 - loss: 0.3639 - val_accuracy: 0.9817 - val_loss: 0.3877 - learning_rate: 3.0000e-04
# Epoch 35/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9952 - loss: 0.3612
# Epoch 35: val_accuracy did not improve from 0.98170
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9951 - loss: 0.3612 - val_accuracy: 0.9775 - val_loss: 0.3965 - learning_rate: 3.0000e-04
# Epoch 36/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9944 - loss: 0.3609
# Epoch 36: val_accuracy did not improve from 0.98170
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9944 - loss: 0.3609 - val_accuracy: 0.9807 - val_loss: 0.3890 - learning_rate: 3.0000e-04
# Epoch 37/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9934 - loss: 0.3632
# Epoch 37: val_accuracy did not improve from 0.98170
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9934 - loss: 0.3632 - val_accuracy: 0.9794 - val_loss: 0.3866 - learning_rate: 3.0000e-04
# Epoch 38/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9959 - loss: 0.3580
# Epoch 38: val_accuracy improved from 0.98170 to 0.98361, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 216ms/step - accuracy: 0.9958 - loss: 0.3580 - val_accuracy: 0.9836 - val_loss: 0.3846 - learning_rate: 3.0000e-04
# Epoch 39/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9954 - loss: 0.3578
# Epoch 39: val_accuracy did not improve from 0.98361
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.9954 - loss: 0.3578 - val_accuracy: 0.9825 - val_loss: 0.3839 - learning_rate: 3.0000e-04
# Epoch 40/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9954 - loss: 0.3566
# Epoch 40: val_accuracy did not improve from 0.98361
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.9954 - loss: 0.3566 - val_accuracy: 0.9822 - val_loss: 0.3850 - learning_rate: 3.0000e-04
# Epoch 41/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9944 - loss: 0.3593
# Epoch 41: val_accuracy did not improve from 0.98361
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.9944 - loss: 0.3593 - val_accuracy: 0.9785 - val_loss: 0.3907 - learning_rate: 3.0000e-04
# Epoch 42/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9957 - loss: 0.3544
# Epoch 42: val_accuracy did not improve from 0.98361
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9957 - loss: 0.3544 - val_accuracy: 0.9816 - val_loss: 0.3835 - learning_rate: 3.0000e-04
# Epoch 43/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9963 - loss: 0.3535
# Epoch 43: val_accuracy did not improve from 0.98361
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9964 - loss: 0.3535 - val_accuracy: 0.9815 - val_loss: 0.3820 - learning_rate: 3.0000e-04
# Epoch 44/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9974 - loss: 0.3509
# Epoch 44: val_accuracy did not improve from 0.98361
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9974 - loss: 0.3509 - val_accuracy: 0.9816 - val_loss: 0.3837 - learning_rate: 3.0000e-04
# Epoch 45/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9969 - loss: 0.3519
# Epoch 45: val_accuracy did not improve from 0.98361
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.9969 - loss: 0.3519 - val_accuracy: 0.9828 - val_loss: 0.3827 - learning_rate: 3.0000e-04
# Epoch 46/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9973 - loss: 0.3520
# Epoch 46: val_accuracy did not improve from 0.98361
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.9973 - loss: 0.3519 - val_accuracy: 0.9822 - val_loss: 0.3826 - learning_rate: 3.0000e-04
# Epoch 47/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9973 - loss: 0.3488
# Epoch 47: val_accuracy did not improve from 0.98361
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9974 - loss: 0.3487 - val_accuracy: 0.9831 - val_loss: 0.3785 - learning_rate: 1.5000e-04
# Epoch 48/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9983 - loss: 0.3460
# Epoch 48: val_accuracy did not improve from 0.98361
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9983 - loss: 0.3460 - val_accuracy: 0.9831 - val_loss: 0.3779 - learning_rate: 1.5000e-04
# Epoch 49/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9984 - loss: 0.3456
# Epoch 49: val_accuracy improved from 0.98361 to 0.98409, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.9984 - loss: 0.3456 - val_accuracy: 0.9841 - val_loss: 0.3773 - learning_rate: 1.5000e-04
# Epoch 50/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9985 - loss: 0.3445
# Epoch 50: val_accuracy did not improve from 0.98409
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9985 - loss: 0.3445 - val_accuracy: 0.9830 - val_loss: 0.3784 - learning_rate: 1.5000e-04
# Epoch 51/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9985 - loss: 0.3449
# Epoch 51: val_accuracy did not improve from 0.98409
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9985 - loss: 0.3449 - val_accuracy: 0.9837 - val_loss: 0.3764 - learning_rate: 1.5000e-04
# Epoch 52/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.9985 - loss: 0.3446
# Epoch 52: val_accuracy did not improve from 0.98409
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.9985 - loss: 0.3446 - val_accuracy: 0.9831 - val_loss: 0.3785 - learning_rate: 1.5000e-04
# Epoch 53/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9989 - loss: 0.3439
# Epoch 53: val_accuracy improved from 0.98409 to 0.98433, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - accuracy: 0.9989 - loss: 0.3439 - val_accuracy: 0.9843 - val_loss: 0.3770 - learning_rate: 1.5000e-04
# Epoch 54/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9984 - loss: 0.3446
# Epoch 54: val_accuracy did not improve from 0.98433
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.9984 - loss: 0.3446 - val_accuracy: 0.9841 - val_loss: 0.3780 - learning_rate: 1.5000e-04
# Epoch 55/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9988 - loss: 0.3434
# Epoch 55: val_accuracy did not improve from 0.98433
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 209ms/step - accuracy: 0.9988 - loss: 0.3434 - val_accuracy: 0.9841 - val_loss: 0.3767 - learning_rate: 1.5000e-04
# Epoch 56/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9989 - loss: 0.3434
# Epoch 56: val_accuracy did not improve from 0.98433
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 208ms/step - accuracy: 0.9989 - loss: 0.3434 - val_accuracy: 0.9830 - val_loss: 0.3800 - learning_rate: 1.5000e-04
# Epoch 57/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9981 - loss: 0.3431
# Epoch 57: val_accuracy did not improve from 0.98433
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 212ms/step - accuracy: 0.9982 - loss: 0.3431 - val_accuracy: 0.9833 - val_loss: 0.3797 - learning_rate: 1.5000e-04
# Epoch 58/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9985 - loss: 0.3426
# Epoch 58: val_accuracy did not improve from 0.98433
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 216ms/step - accuracy: 0.9985 - loss: 0.3426 - val_accuracy: 0.9839 - val_loss: 0.3779 - learning_rate: 1.5000e-04
# Epoch 59/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.9991 - loss: 0.3422
# Epoch 59: val_accuracy improved from 0.98433 to 0.98445, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 227ms/step - accuracy: 0.9991 - loss: 0.3422 - val_accuracy: 0.9845 - val_loss: 0.3769 - learning_rate: 1.5000e-04
# Epoch 60/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9986 - loss: 0.3430
# Epoch 60: val_accuracy did not improve from 0.98445
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 16s 210ms/step - accuracy: 0.9986 - loss: 0.3430 - val_accuracy: 0.9841 - val_loss: 0.3765 - learning_rate: 1.5000e-04

# %%
def predict_by_batching(model, idx, batch_size, X, windowSize):

    preds=[]

    for i in tqdm(range(0,len(idx),batch_size)):
        batch=createImageCubes(X,idx[i:i+batch_size],windowSize)
        preds.append(model.predict(batch,verbose=0))

    return np.concatenate(preds)

# %%
Y_pred_test=predict_by_batching(model,X_test_idx,2000,data,window_size)

y_pred_test=np.argmax(Y_pred_test,axis=1)

oa=accuracy_score(y_test,y_pred_test)
kappa=cohen_kappa_score(y_test,y_pred_test)

cm=confusion_matrix(y_test,y_pred_test)

class_acc=cm.diagonal()/cm.sum(axis=1)
aa=np.mean(class_acc)

print("Overall Accuracy:",round(oa*100,2))
print("Average Accuracy:",round(aa*100,2))
print("Kappa:",round(kappa*100,2))
# Out:
# 100%|██████████| 265/265 [04:06<00:00,  1.08it/s]
# Overall Accuracy: 98.27
# Average Accuracy: 96.5
# Kappa: 98.03

# %%
import pandas as pd
import numpy as np

# -----------------------------
# Compute per-class accuracy
# -----------------------------
class_accuracy = cm.diagonal() / cm.sum(axis=1) * 100

rows = []

for i in range(len(class_name)):

    train_count = (y_train.argmax(axis=1) == i).sum()
    val_count   = (y_val.argmax(axis=1) == i).sum()
    test_count  = (y_test == i).sum()
    total_count = (gt == (i+1)).sum()

    rows.append([
        class_name[i],
        train_count,
        val_count,
        test_count,
        total_count,
        round(class_accuracy[i], 2)
    ])

# -----------------------------
# Create DataFrame
# -----------------------------
df = pd.DataFrame(
    rows,
    columns=[
        "Class",
        "Train",
        "Val",
        "Test",
        "Total",
        "SS-MixNet (%)"
    ]
)

# -----------------------------
# Summary Metrics
# -----------------------------
summary_rows = pd.DataFrame([
    ["OA (%)", "", "", "", "", round(oa * 100, 2)],
    ["AA (%)", "", "", "", "", round(aa * 100, 2)],
    ["Kappa (×100)", "", "", "", "", round(kappa * 100, 2)]
], columns=df.columns)

df_final = pd.concat([df, summary_rows], ignore_index=True)

# -----------------------------
# Pretty Print Table
# -----------------------------
print("\n")
print("=" * 90)
print(f"{'Classification Performance of SS-MixNet on ' + DATASET:^90}")
print("=" * 90)

print(f"{'Class':<25}{'Train':>8}{'Val':>8}{'Test':>10}{'Total':>10}{'Accuracy (%)':>15}")
print("-" * 90)

for i in range(len(class_name)):
    print(f"{df.iloc[i,0]:<25}"
          f"{df.iloc[i,1]:>8}"
          f"{df.iloc[i,2]:>8}"
          f"{df.iloc[i,3]:>10}"
          f"{df.iloc[i,4]:>10}"
          f"{df.iloc[i,5]:>15}")

print("-" * 90)

print(f"{'Overall Accuracy (OA)':<25}{'':>8}{'':>8}{'':>10}{'':>10}{round(oa*100,2):>15}")
print(f"{'Average Accuracy (AA)':<25}{'':>8}{'':>8}{'':>10}{'':>10}{round(aa*100,2):>15}")
print(f"{'Kappa (×100)':<25}{'':>8}{'':>8}{'':>10}{'':>10}{round(kappa*100,2):>15}")

print("=" * 90)
# Out:
# ==========================================================================================
#                   Classification Performance of SS-MixNet on Tangdaowan
# ==========================================================================================
# Class                       Train     Val      Test     Total   Accuracy (%)
# ------------------------------------------------------------------------------------------
# Rubber track                  904     388     24557     25849           99.9
# Flaggingv                    1945     833     52775     55553          99.53
# Sandy                        1191     511     32335     34037          98.07
# Asphalt                      2124     911     57655     60690          99.59
# Boardwalk                      65      28      1769      1862          94.52
# Rocky shallows               1299     557     35269     37125          97.22
# Grassland                     494     212     13421     14127          88.05
# Bulrush                      2243     961     60883     64087          99.98
# Gravel road                  1075     460     29160     30695          99.65
# Ligustrum vicaryi              62      27      1694      1783           94.1
# Coniferous pine               743     319     20174     21236          93.88
# Spiraea                        27      11       711       749          92.55
# Bare soil                      59      25      1602      1686          99.81
# Buxus sinica                   31      13       842       886          95.72
# Photinia serrulata            491     210     13319     14020          92.17
# Populus                      4931    2114    133859    140904          98.34
# Ulmus pumila L                343     147      9312      9802          93.94
# Seawater                     1480     634     40161     42275          100.0
# ------------------------------------------------------------------------------------------
# Overall Accuracy (OA)                                                  98.27
# Average Accuracy (AA)                                                   96.5
# Kappa (×100)                                                           98.03
# ==========================================================================================

# %%
def get_class_map(model, X, label, window_size):

    indexes = np.argwhere(label != None)

    indexes = [tuple(i) for i in indexes]

    preds = []

    for i in tqdm(range(0, len(indexes), 2000)):
        batch_idx = indexes[i:i+2000]

        patches = createImageCubes(X, batch_idx, window_size)

        y_pred = model.predict(patches, verbose=0)

        preds.append(y_pred)

    preds = np.concatenate(preds)

    preds = np.argmax(preds, axis=1)

    Predicted_Class_Map = np.reshape(preds, label.shape)

    return Predicted_Class_Map

# %%
def img_display(data=None, rgb_band=None, classes=None, title=None, figsize=(7,7)):

    if data is not None:
        im_rgb = data[:,:,rgb_band]
        im_rgb = im_rgb / np.max(im_rgb) * 255
        im_rgb = np.asarray(im_rgb, np.uint8)

        plt.figure(figsize=figsize)
        plt.imshow(im_rgb)
        plt.title(title)
        plt.axis('off')
        plt.show()

    elif classes is not None:

        unique_classes = np.unique(classes)

        rgb_class = np.zeros((classes.shape[0], classes.shape[1], 3))

        colors = spectral.spy_colors

        for i in unique_classes:
            rgb_class[classes == i] = colors[i]

        rgb_class = np.asarray(rgb_class, np.uint8)

        plt.figure(figsize=figsize)
        plt.imshow(rgb_class)
        plt.title(title)
        plt.axis('off')
        plt.show()

# %%
model.load_weights(f"{DATASET}_SS_MixNet.keras")

Predicted_Class_Map = get_class_map(model, data, gt, window_size)

img_display(classes=Predicted_Class_Map, title='Predicted')
# Out:
# 100%|██████████| 749/749 [10:46<00:00,  1.16it/s]

# %%
model.save("SS_MixNet_ECA.keras")

from google.colab import files
files.download("SS_MixNet_ECA.keras")

# %%
model.save_weights("SS_MixNet_ECA_T4.weights.h5")

from google.colab import files
files.download("SS_MixNet_ECA_T4.weights.h5")

# %%
import numpy as np

np.save("X_test_idx.npy", X_test_idx)
np.save("y_test.npy", y_test)

from google.colab import files
files.download("X_test_idx.npy")
files.download("y_test.npy")
