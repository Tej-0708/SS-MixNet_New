# %%
# !pip install spectral tqdm scikit-learn

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Collecting spectral
#   Downloading spectral-0.24-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from spectral) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Downloading spectral-0.24-py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.0/249.0 kB 9.6 MB/s eta 0:00:00
# Installing collected packages: spectral
# Successfully installed spectral-0.24
# Mounted at /content/drive

# %%
import os
import numpy as np
import tensorflow as tf
from scipy.io import loadmat
from tqdm import tqdm
import matplotlib.pyplot as plt
import spectral

from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import minmax_scale
from sklearn.metrics import accuracy_score, confusion_matrix, cohen_kappa_score

from tensorflow.keras.layers import (
    Input, Conv3D, Conv2D, Dense, Dropout, Reshape,
    Concatenate, Add, Multiply,
    GlobalAveragePooling2D,
    Permute
)

from tensorflow.keras.models import Model

# %%
from tensorflow.keras import mixed_precision

mixed_precision.set_global_policy('mixed_float16')

print("Policy:", mixed_precision.global_policy())
# Out:
# Policy: <DTypePolicy "mixed_float16">

# %%
def loadData(name):

    data_path = '/content/drive/MyDrive/datasets'

    if name == 'Tangdaowan':
        data = loadmat(os.path.join(data_path, 'QUH-Tangdaowan.mat'))['Tangdaowan']
        labels = loadmat(os.path.join(data_path, 'QUH-Tangdaowan_GT.mat'))['TangdaowanGT']
        class_name = [
            "Rubber track","Flaggingv","Sandy","Asphalt","Boardwalk",
            "Rocky shallows","Grassland","Bulrush","Gravel road",
            "Ligustrum vicaryi","Coniferous pine","Spiraea","Bare soil",
            "Buxus sinica","Photinia serrulata","Populus",
            "Ulmus pumila L","Seawater"
        ]

    elif name == 'Qingyun':
        data = loadmat(os.path.join(data_path, 'QUH-Qingyun.mat'))['Chengqu']
        labels = loadmat(os.path.join(data_path, 'QUH-Qingyun_GT.mat'))['ChengquGT']
        class_name = [
            "Trees","Concrete building","Car",
            "Ironhide building","Plastic playground","Asphalt road"
        ]

    elif name == 'Pingan':
        data = loadmat(os.path.join(data_path, 'QUH-Pingan.mat'))['Haigang']
        labels = loadmat(os.path.join(data_path, 'QUH-Pingan_GT.mat'))['HaigangGT']
        class_name = [
            "Ship","Seawater","Trees","Concrete structure building",
            "Floating pier","Asphalt road","Brick houses",
            "Steel houses","Wharf construction land","Car","Road"
        ]

    return data, labels, class_name

# %%
def applyPCA(X, numComponents=15):

    newX = np.reshape(X, (-1, X.shape[2]))

    pca = PCA(n_components=numComponents)

    newX = pca.fit_transform(newX)

    newX = minmax_scale(newX, axis=1)

    newX = np.reshape(newX,(X.shape[0],X.shape[1],numComponents))

    return newX

# %%
def get_img_indexes(class_map, removeZeroindexes=True):

    if removeZeroindexes:
        indices = np.argwhere(class_map != 0)
    else:
        indices = np.argwhere(class_map != None)

    labels = class_map[indices[:,0], indices[:,1]]

    indices = [tuple(i) for i in indices]

    return indices, np.array(labels.tolist()) - 1

# %%
def splitTrainTestSet(X, y, testRatio):

    return train_test_split(
        X,
        y,
        test_size=testRatio,
        stratify=y,
        random_state=42
    )

# %%
def createImageCubes(X, indices, windowSize):

    margin = windowSize // 2

    N,M,P = X.shape

    X_padded = np.zeros((N+2*margin, M+2*margin, P))

    X_padded[margin:N+margin, margin:M+margin,:] = X

    patches=[]

    for idx in indices:

        i,j = idx

        i+=margin
        j+=margin

        patch = X_padded[i-margin:i+margin+1, j-margin:j+margin+1,:]

        patches.append(patch)

    patches=np.array(patches)

    patches = patches[...,np.newaxis]

    return patches

# %%
def spectral_mixer_block(x, hidden_dim, num_blocks=2):

    H,W,C,D = x.shape[1:]

    x = Permute((1,2,4,3))(x)

    x = Reshape((H*W, D, C))(x)

    for _ in range(num_blocks):

        x1 = Dense(hidden_dim, activation='gelu')(x)

        x1 = Dense(C)(x1)

        x = Add()([x,x1])

    return Reshape((H,W,C,D))(x)

# %%
def spatial_mixer_block(x, hidden_dim, num_blocks=2):

    H,W,C,D = x.shape[1:]

    x = Permute((3,4,1,2))(x)

    x = Reshape((C,D,H*W))(x)

    for _ in range(num_blocks):

        x1 = Dense(hidden_dim, activation='gelu')(x)

        x1 = Dense(H*W)(x1)

        x = Add()([x,x1])

    x = Permute((3,1,2))(x)

    return Reshape((H,W,C,D))(x)

# %%
from tensorflow.keras.layers import Lambda, Concatenate, Conv2D, Multiply

def coordinate_attention(x, reduction=32):

    H = x.shape[1]
    W = x.shape[2]
    C = x.shape[3]

    # Height pooling
    pool_h = Lambda(lambda z: tf.reduce_mean(z, axis=2, keepdims=True))(x)

    # Width pooling
    pool_w = Lambda(lambda z: tf.reduce_mean(z, axis=1, keepdims=True))(x)
    pool_w = Lambda(lambda z: tf.transpose(z, perm=[0,2,1,3]))(pool_w)

    y = Concatenate(axis=1)([pool_h, pool_w])

    mid_channels = max(8, C // reduction)

    y = Conv2D(mid_channels, 1, activation='gelu', padding='same')(y)

    # Split features
    x_h = Lambda(lambda z: z[:, :H, :, :])(y)
    x_w = Lambda(lambda z: z[:, H:, :, :])(y)

    x_w = Lambda(lambda z: tf.transpose(z, perm=[0,2,1,3]))(x_w)

    a_h = Conv2D(C, 1, activation='sigmoid', padding='same')(x_h)
    a_w = Conv2D(C, 1, activation='sigmoid', padding='same')(x_w)

    out = Multiply()([x, a_h])
    out = Multiply()([out, a_w])

    return out

# %%
def SS_MixNet(img_list, num_classes, mixer_dim=256):

    input_shape = img_list.shape[1:]

    inp = Input(shape=input_shape)

    x = Conv3D(32,(3,3,3),padding='same',activation='gelu')(inp)
    x = Conv3D(64,(3,3,3),padding='same',activation='gelu')(x)

    x_spe = spectral_mixer_block(x, mixer_dim)
    x_spa = spatial_mixer_block(x, mixer_dim)

    x = Concatenate(axis=4)([x_spe,x_spa])

    H,W,C,F = x.shape[1:]

    x = Reshape((H,W,C*F))(x)

    x = coordinate_attention(x)

    res = Conv2D(x.shape[-1],1,padding='same',activation='gelu')(x)

    x = Add()([x,res])

    x = GlobalAveragePooling2D()(x)

    x = Dropout(0.4)(x)

    out = Dense(num_classes,activation='softmax',dtype='float32')(x)

    model = Model(inp,out)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
        metrics=['accuracy']
    )

    return model

# %%
DATASET='Tangdaowan'

data, gt, class_name = loadData(DATASET)

print(data.shape)
# Out:
# (1740, 860, 176)

# %%
data = applyPCA(data, numComponents=15)

# %%
indexes, labels = get_img_indexes(gt)

X_train_idx, X_test_idx, y_train, y_test = splitTrainTestSet(indexes,labels,0.95)

X_train_idx, X_val_idx, y_train, y_val = splitTrainTestSet(X_train_idx,y_train,0.30)

# %%
window_size=9

X_train = createImageCubes(data,X_train_idx,window_size)
X_val = createImageCubes(data,X_val_idx,window_size)

y_train = tf.keras.utils.to_categorical(y_train)
y_val = tf.keras.utils.to_categorical(y_val)

# %%
model = SS_MixNet(
    X_train,
    num_classes=len(class_name),
    mixer_dim=256
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 9, 9, 15,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_2 (Conv3D)   │ (None, 9, 9, 15,  │        896 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_3 (Conv3D)   │ (None, 9, 9, 15,  │     55,360 │ conv3d_2[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_4 (Permute) │ (None, 15, 64, 9, │          0 │ conv3d_3[0][0]    │
# │                     │ 9)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_3 (Permute) │ (None, 9, 9, 64,  │          0 │ conv3d_3[0][0]    │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_7 (Reshape) │ (None, 15, 64,    │          0 │ permute_4[0][0]   │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_5 (Reshape) │ (None, 81, 64,    │          0 │ permute_3[0][0]   │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 15, 64,    │     20,992 │ reshape_7[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 81, 64,    │      4,096 │ reshape_5[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 15, 64,    │     20,817 │ dense_12[0][0]    │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 81, 64,    │      3,855 │ dense_8[0][0]     │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 15, 64,    │          0 │ reshape_7[0][0],  │
# │                     │ 81)               │            │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 81, 64,    │          0 │ reshape_5[0][0],  │
# │                     │ 15)               │            │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 15, 64,    │     20,992 │ add_6[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 81, 64,    │      4,096 │ add_4[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 15, 64,    │     20,817 │ dense_14[0][0]    │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 81, 64,    │      3,855 │ dense_10[0][0]    │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 15, 64,    │          0 │ add_6[0][0],      │
# │                     │ 81)               │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 81, 64,    │          0 │ add_4[0][0],      │
# │                     │ 15)               │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_5 (Permute) │ (None, 81, 15,    │          0 │ add_7[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_6 (Reshape) │ (None, 9, 9, 15,  │          0 │ add_5[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_8 (Reshape) │ (None, 9, 9, 15,  │          0 │ permute_5[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 9, 9, 15,  │          0 │ reshape_6[0][0],  │
# │ (Concatenate)       │ 128)              │            │ reshape_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_9 (Reshape) │ (None, 9, 9,      │          0 │ concatenate_1[0]… │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 1, 9,      │          0 │ reshape_9[0][0]   │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 9, 1,      │          0 │ reshape_9[0][0]   │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, 9, 1,      │          0 │ lambda_1[0][0]    │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 18, 1,     │          0 │ lambda[0][0],     │
# │ (Concatenate)       │ 1920)             │            │ lambda_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 18, 1, 60) │    115,260 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_3 (Lambda)   │ (None, 9, 1, 60)  │          0 │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_4 (Lambda)   │ (None, 9, 1, 60)  │          0 │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 9, 1,      │    117,120 │ lambda_3[0][0]    │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_5 (Lambda)   │ (None, 1, 9, 60)  │          0 │ lambda_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 9, 9,      │          0 │ reshape_9[0][0],  │
# │                     │ 1920)             │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 1, 9,      │    117,120 │ lambda_5[0][0]    │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 9, 9,      │          0 │ multiply[0][0],   │
# │ (Multiply)          │ 1920)             │            │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 9, 9,      │  3,688,320 │ multiply_1[0][0]  │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 9, 9,      │          0 │ multiply_1[0][0], │
# │                     │ 1920)             │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1920)      │          0 │ add_8[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1920)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 18)        │     34,578 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,228,174 (16.13 MB)
#  Trainable params: 4,228,174 (16.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    f"{DATASET}_SS_MixNet_CA.keras",
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=8,
    min_lr=5e-5
)

history = model.fit(
    X_train,
    y_train,
    epochs=60,
    batch_size=256,
    validation_data=(X_val,y_val),
    callbacks=[checkpoint, lr_callback]
)
# Out:
# Epoch 1/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 649ms/step - accuracy: 0.3666 - loss: 2.2526
# Epoch 1: val_accuracy improved from -inf to 0.64442, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 125s 970ms/step - accuracy: 0.3682 - loss: 2.2472 - val_accuracy: 0.6444 - val_loss: 1.2749 - learning_rate: 3.0000e-04
# Epoch 2/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.7020 - loss: 1.1793
# Epoch 2: val_accuracy improved from 0.64442 to 0.80421, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 263ms/step - accuracy: 0.7030 - loss: 1.1761 - val_accuracy: 0.8042 - val_loss: 0.8878 - learning_rate: 3.0000e-04
# Epoch 3/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.7968 - loss: 0.8804
# Epoch 3: val_accuracy improved from 0.80421 to 0.82299, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 250ms/step - accuracy: 0.7971 - loss: 0.8796 - val_accuracy: 0.8230 - val_loss: 0.8038 - learning_rate: 3.0000e-04
# Epoch 4/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8372 - loss: 0.7784
# Epoch 4: val_accuracy improved from 0.82299 to 0.88016, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 239ms/step - accuracy: 0.8374 - loss: 0.7777 - val_accuracy: 0.8802 - val_loss: 0.6811 - learning_rate: 3.0000e-04
# Epoch 5/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.8766 - loss: 0.6880
# Epoch 5: val_accuracy improved from 0.88016 to 0.90360, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.8769 - loss: 0.6873 - val_accuracy: 0.9036 - val_loss: 0.6091 - learning_rate: 3.0000e-04
# Epoch 6/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.9050 - loss: 0.6077
# Epoch 6: val_accuracy improved from 0.90360 to 0.92405, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 251ms/step - accuracy: 0.9051 - loss: 0.6074 - val_accuracy: 0.9241 - val_loss: 0.5608 - learning_rate: 3.0000e-04
# Epoch 7/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.9249 - loss: 0.5594
# Epoch 7: val_accuracy improved from 0.92405 to 0.93374, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 248ms/step - accuracy: 0.9250 - loss: 0.5592 - val_accuracy: 0.9337 - val_loss: 0.5272 - learning_rate: 3.0000e-04
# Epoch 8/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9334 - loss: 0.5316
# Epoch 8: val_accuracy improved from 0.93374 to 0.94056, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 247ms/step - accuracy: 0.9335 - loss: 0.5314 - val_accuracy: 0.9406 - val_loss: 0.4993 - learning_rate: 3.0000e-04
# Epoch 9/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9414 - loss: 0.5046
# Epoch 9: val_accuracy improved from 0.94056 to 0.94773, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 245ms/step - accuracy: 0.9415 - loss: 0.5045 - val_accuracy: 0.9477 - val_loss: 0.4848 - learning_rate: 3.0000e-04
# Epoch 10/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9490 - loss: 0.4837
# Epoch 10: val_accuracy improved from 0.94773 to 0.95120, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 244ms/step - accuracy: 0.9490 - loss: 0.4837 - val_accuracy: 0.9512 - val_loss: 0.4751 - learning_rate: 3.0000e-04
# Epoch 11/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9507 - loss: 0.4809
# Epoch 11: val_accuracy improved from 0.95120 to 0.95599, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 247ms/step - accuracy: 0.9507 - loss: 0.4808 - val_accuracy: 0.9560 - val_loss: 0.4654 - learning_rate: 3.0000e-04
# Epoch 12/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9568 - loss: 0.4639
# Epoch 12: val_accuracy improved from 0.95599 to 0.95934, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 247ms/step - accuracy: 0.9568 - loss: 0.4638 - val_accuracy: 0.9593 - val_loss: 0.4516 - learning_rate: 3.0000e-04
# Epoch 13/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9588 - loss: 0.4541
# Epoch 13: val_accuracy improved from 0.95934 to 0.96268, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 247ms/step - accuracy: 0.9589 - loss: 0.4540 - val_accuracy: 0.9627 - val_loss: 0.4427 - learning_rate: 3.0000e-04
# Epoch 14/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9662 - loss: 0.4380
# Epoch 14: val_accuracy improved from 0.96268 to 0.96579, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 247ms/step - accuracy: 0.9662 - loss: 0.4381 - val_accuracy: 0.9658 - val_loss: 0.4325 - learning_rate: 3.0000e-04
# Epoch 15/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9658 - loss: 0.4328
# Epoch 15: val_accuracy did not improve from 0.96579
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 239ms/step - accuracy: 0.9658 - loss: 0.4327 - val_accuracy: 0.9654 - val_loss: 0.4314 - learning_rate: 3.0000e-04
# Epoch 16/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9728 - loss: 0.4221
# Epoch 16: val_accuracy improved from 0.96579 to 0.96735, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 245ms/step - accuracy: 0.9728 - loss: 0.4222 - val_accuracy: 0.9673 - val_loss: 0.4312 - learning_rate: 3.0000e-04
# Epoch 17/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9703 - loss: 0.4220
# Epoch 17: val_accuracy improved from 0.96735 to 0.96759, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 247ms/step - accuracy: 0.9704 - loss: 0.4219 - val_accuracy: 0.9676 - val_loss: 0.4233 - learning_rate: 3.0000e-04
# Epoch 18/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9744 - loss: 0.4151
# Epoch 18: val_accuracy improved from 0.96759 to 0.97141, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 244ms/step - accuracy: 0.9744 - loss: 0.4151 - val_accuracy: 0.9714 - val_loss: 0.4215 - learning_rate: 3.0000e-04
# Epoch 19/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9754 - loss: 0.4122
# Epoch 19: val_accuracy improved from 0.97141 to 0.97273, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 245ms/step - accuracy: 0.9754 - loss: 0.4122 - val_accuracy: 0.9727 - val_loss: 0.4101 - learning_rate: 3.0000e-04
# Epoch 20/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9796 - loss: 0.4033
# Epoch 20: val_accuracy improved from 0.97273 to 0.97572, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 245ms/step - accuracy: 0.9796 - loss: 0.4032 - val_accuracy: 0.9757 - val_loss: 0.4073 - learning_rate: 3.0000e-04
# Epoch 21/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9778 - loss: 0.4046
# Epoch 21: val_accuracy improved from 0.97572 to 0.97680, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 245ms/step - accuracy: 0.9778 - loss: 0.4046 - val_accuracy: 0.9768 - val_loss: 0.4053 - learning_rate: 3.0000e-04
# Epoch 22/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9830 - loss: 0.3952
# Epoch 22: val_accuracy improved from 0.97680 to 0.97728, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 248ms/step - accuracy: 0.9829 - loss: 0.3953 - val_accuracy: 0.9773 - val_loss: 0.3999 - learning_rate: 3.0000e-04
# Epoch 23/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9831 - loss: 0.3898
# Epoch 23: val_accuracy improved from 0.97728 to 0.97799, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 247ms/step - accuracy: 0.9831 - loss: 0.3898 - val_accuracy: 0.9780 - val_loss: 0.3955 - learning_rate: 3.0000e-04
# Epoch 24/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9834 - loss: 0.3895
# Epoch 24: val_accuracy did not improve from 0.97799
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 241ms/step - accuracy: 0.9834 - loss: 0.3895 - val_accuracy: 0.9760 - val_loss: 0.3990 - learning_rate: 3.0000e-04
# Epoch 25/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9862 - loss: 0.3852
# Epoch 25: val_accuracy improved from 0.97799 to 0.98003, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 247ms/step - accuracy: 0.9862 - loss: 0.3853 - val_accuracy: 0.9800 - val_loss: 0.3929 - learning_rate: 3.0000e-04
# Epoch 26/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9870 - loss: 0.3825
# Epoch 26: val_accuracy improved from 0.98003 to 0.98015, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 244ms/step - accuracy: 0.9870 - loss: 0.3825 - val_accuracy: 0.9801 - val_loss: 0.3906 - learning_rate: 3.0000e-04
# Epoch 27/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9875 - loss: 0.3803
# Epoch 27: val_accuracy did not improve from 0.98015
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 239ms/step - accuracy: 0.9875 - loss: 0.3803 - val_accuracy: 0.9797 - val_loss: 0.3917 - learning_rate: 3.0000e-04
# Epoch 28/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9882 - loss: 0.3800
# Epoch 28: val_accuracy did not improve from 0.98015
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 239ms/step - accuracy: 0.9881 - loss: 0.3800 - val_accuracy: 0.9795 - val_loss: 0.3900 - learning_rate: 3.0000e-04
# Epoch 29/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9885 - loss: 0.3787
# Epoch 29: val_accuracy improved from 0.98015 to 0.98158, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 245ms/step - accuracy: 0.9885 - loss: 0.3786 - val_accuracy: 0.9816 - val_loss: 0.3866 - learning_rate: 3.0000e-04
# Epoch 30/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.9899 - loss: 0.3732
# Epoch 30: val_accuracy improved from 0.98158 to 0.98314, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 246ms/step - accuracy: 0.9899 - loss: 0.3732 - val_accuracy: 0.9831 - val_loss: 0.3842 - learning_rate: 3.0000e-04
# Epoch 31/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9900 - loss: 0.3709
# Epoch 31: val_accuracy did not improve from 0.98314
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9900 - loss: 0.3708 - val_accuracy: 0.9809 - val_loss: 0.3864 - learning_rate: 3.0000e-04
# Epoch 32/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9897 - loss: 0.3727
# Epoch 32: val_accuracy improved from 0.98314 to 0.98373, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 246ms/step - accuracy: 0.9897 - loss: 0.3727 - val_accuracy: 0.9837 - val_loss: 0.3837 - learning_rate: 3.0000e-04
# Epoch 33/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9922 - loss: 0.3670
# Epoch 33: val_accuracy did not improve from 0.98373
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9922 - loss: 0.3670 - val_accuracy: 0.9830 - val_loss: 0.3839 - learning_rate: 3.0000e-04
# Epoch 34/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9896 - loss: 0.3738
# Epoch 34: val_accuracy did not improve from 0.98373
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 242ms/step - accuracy: 0.9896 - loss: 0.3737 - val_accuracy: 0.9835 - val_loss: 0.3805 - learning_rate: 3.0000e-04
# Epoch 35/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9920 - loss: 0.3677
# Epoch 35: val_accuracy did not improve from 0.98373
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 241ms/step - accuracy: 0.9920 - loss: 0.3676 - val_accuracy: 0.9816 - val_loss: 0.3838 - learning_rate: 3.0000e-04
# Epoch 36/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9912 - loss: 0.3660
# Epoch 36: val_accuracy improved from 0.98373 to 0.98445, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 248ms/step - accuracy: 0.9912 - loss: 0.3659 - val_accuracy: 0.9845 - val_loss: 0.3785 - learning_rate: 3.0000e-04
# Epoch 37/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9933 - loss: 0.3632
# Epoch 37: val_accuracy did not improve from 0.98445
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 240ms/step - accuracy: 0.9933 - loss: 0.3631 - val_accuracy: 0.9834 - val_loss: 0.3779 - learning_rate: 3.0000e-04
# Epoch 38/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9934 - loss: 0.3618
# Epoch 38: val_accuracy improved from 0.98445 to 0.98469, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 245ms/step - accuracy: 0.9934 - loss: 0.3618 - val_accuracy: 0.9847 - val_loss: 0.3778 - learning_rate: 3.0000e-04
# Epoch 39/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9940 - loss: 0.3611
# Epoch 39: val_accuracy improved from 0.98469 to 0.98505, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 247ms/step - accuracy: 0.9939 - loss: 0.3611 - val_accuracy: 0.9850 - val_loss: 0.3750 - learning_rate: 3.0000e-04
# Epoch 40/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9933 - loss: 0.3619
# Epoch 40: val_accuracy did not improve from 0.98505
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9933 - loss: 0.3619 - val_accuracy: 0.9828 - val_loss: 0.3801 - learning_rate: 3.0000e-04
# Epoch 41/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9945 - loss: 0.3594
# Epoch 41: val_accuracy did not improve from 0.98505
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9945 - loss: 0.3594 - val_accuracy: 0.9842 - val_loss: 0.3748 - learning_rate: 3.0000e-04
# Epoch 42/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9942 - loss: 0.3581
# Epoch 42: val_accuracy did not improve from 0.98505
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 241ms/step - accuracy: 0.9942 - loss: 0.3580 - val_accuracy: 0.9850 - val_loss: 0.3738 - learning_rate: 3.0000e-04
# Epoch 43/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9939 - loss: 0.3575
# Epoch 43: val_accuracy did not improve from 0.98505
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 241ms/step - accuracy: 0.9939 - loss: 0.3575 - val_accuracy: 0.9846 - val_loss: 0.3730 - learning_rate: 3.0000e-04
# Epoch 44/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9958 - loss: 0.3544
# Epoch 44: val_accuracy improved from 0.98505 to 0.98589, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 246ms/step - accuracy: 0.9957 - loss: 0.3544 - val_accuracy: 0.9859 - val_loss: 0.3740 - learning_rate: 3.0000e-04
# Epoch 45/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9961 - loss: 0.3529
# Epoch 45: val_accuracy did not improve from 0.98589
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9961 - loss: 0.3529 - val_accuracy: 0.9853 - val_loss: 0.3718 - learning_rate: 3.0000e-04
# Epoch 46/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9956 - loss: 0.3528
# Epoch 46: val_accuracy did not improve from 0.98589
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 239ms/step - accuracy: 0.9956 - loss: 0.3528 - val_accuracy: 0.9841 - val_loss: 0.3721 - learning_rate: 3.0000e-04
# Epoch 47/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9965 - loss: 0.3516
# Epoch 47: val_accuracy improved from 0.98589 to 0.98720, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 245ms/step - accuracy: 0.9964 - loss: 0.3516 - val_accuracy: 0.9872 - val_loss: 0.3707 - learning_rate: 3.0000e-04
# Epoch 48/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9964 - loss: 0.3505
# Epoch 48: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9963 - loss: 0.3505 - val_accuracy: 0.9865 - val_loss: 0.3705 - learning_rate: 3.0000e-04
# Epoch 49/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9969 - loss: 0.3495
# Epoch 49: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 239ms/step - accuracy: 0.9969 - loss: 0.3495 - val_accuracy: 0.9856 - val_loss: 0.3707 - learning_rate: 3.0000e-04
# Epoch 50/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9974 - loss: 0.3483
# Epoch 50: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 239ms/step - accuracy: 0.9974 - loss: 0.3484 - val_accuracy: 0.9862 - val_loss: 0.3700 - learning_rate: 3.0000e-04
# Epoch 51/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9980 - loss: 0.3472
# Epoch 51: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9979 - loss: 0.3472 - val_accuracy: 0.9864 - val_loss: 0.3694 - learning_rate: 3.0000e-04
# Epoch 52/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9972 - loss: 0.3480
# Epoch 52: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9972 - loss: 0.3481 - val_accuracy: 0.9853 - val_loss: 0.3733 - learning_rate: 3.0000e-04
# Epoch 53/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9965 - loss: 0.3503
# Epoch 53: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9965 - loss: 0.3503 - val_accuracy: 0.9867 - val_loss: 0.3687 - learning_rate: 3.0000e-04
# Epoch 54/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9971 - loss: 0.3475
# Epoch 54: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9971 - loss: 0.3475 - val_accuracy: 0.9865 - val_loss: 0.3695 - learning_rate: 3.0000e-04
# Epoch 55/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9977 - loss: 0.3457
# Epoch 55: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9977 - loss: 0.3458 - val_accuracy: 0.9858 - val_loss: 0.3708 - learning_rate: 3.0000e-04
# Epoch 56/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9971 - loss: 0.3456
# Epoch 56: val_accuracy improved from 0.98720 to 0.98816, saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 246ms/step - accuracy: 0.9972 - loss: 0.3455 - val_accuracy: 0.9882 - val_loss: 0.3651 - learning_rate: 1.5000e-04
# Epoch 57/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.9990 - loss: 0.3412
# Epoch 57: val_accuracy did not improve from 0.98816
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9990 - loss: 0.3412 - val_accuracy: 0.9880 - val_loss: 0.3646 - learning_rate: 1.5000e-04
# Epoch 58/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9988 - loss: 0.3409
# Epoch 58: val_accuracy did not improve from 0.98816
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 241ms/step - accuracy: 0.9988 - loss: 0.3409 - val_accuracy: 0.9882 - val_loss: 0.3643 - learning_rate: 1.5000e-04
# Epoch 59/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9986 - loss: 0.3412
# Epoch 59: val_accuracy did not improve from 0.98816
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 241ms/step - accuracy: 0.9986 - loss: 0.3412 - val_accuracy: 0.9874 - val_loss: 0.3651 - learning_rate: 1.5000e-04
# Epoch 60/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.9985 - loss: 0.3416
# Epoch 60: val_accuracy did not improve from 0.98816
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 241ms/step - accuracy: 0.9985 - loss: 0.3416 - val_accuracy: 0.9880 - val_loss: 0.3650 - learning_rate: 1.5000e-04

# %%
def predict_by_batching(model, idx, batch_size, X, windowSize):

    preds=[]

    for i in tqdm(range(0,len(idx),batch_size)):

        batch = createImageCubes(X,idx[i:i+batch_size],windowSize)

        preds.append(model.predict(batch,verbose=0))

    return np.concatenate(preds)

# %%
Y_pred_test = predict_by_batching(model,X_test_idx,2000,data,window_size)

y_pred_test = np.argmax(Y_pred_test,axis=1)

oa = accuracy_score(y_test,y_pred_test)
kappa = cohen_kappa_score(y_test,y_pred_test)

cm = confusion_matrix(y_test,y_pred_test)

class_acc = cm.diagonal()/cm.sum(axis=1)
aa = np.mean(class_acc)

print("Overall Accuracy:",round(oa*100,2))
print("Average Accuracy:",round(aa*100,2))
print("Kappa:",round(kappa*100,2))
# Out:
# 100%|██████████| 265/265 [04:14<00:00,  1.04it/s]
# Overall Accuracy: 98.66
# Average Accuracy: 97.47
# Kappa: 98.47

# %%
import pandas as pd
import numpy as np

# -----------------------------
# Compute per-class accuracy
# -----------------------------
class_accuracy = cm.diagonal() / cm.sum(axis=1) * 100

rows = []

for i in range(len(class_name)):

    train_count = (y_train.argmax(axis=1) == i).sum()
    val_count   = (y_val.argmax(axis=1) == i).sum()
    test_count  = (y_test == i).sum()
    total_count = (gt == (i+1)).sum()

    rows.append([
        class_name[i],
        train_count,
        val_count,
        test_count,
        total_count,
        round(class_accuracy[i], 2)
    ])

# -----------------------------
# Create DataFrame
# -----------------------------
df = pd.DataFrame(
    rows,
    columns=[
        "Class",
        "Train",
        "Val",
        "Test",
        "Total",
        "SS-MixNet (%)"
    ]
)

# -----------------------------
# Summary Metrics
# -----------------------------
summary_rows = pd.DataFrame([
    ["OA (%)", "", "", "", "", round(oa * 100, 2)],
    ["AA (%)", "", "", "", "", round(aa * 100, 2)],
    ["Kappa (×100)", "", "", "", "", round(kappa * 100, 2)]
], columns=df.columns)

df_final = pd.concat([df, summary_rows], ignore_index=True)

# -----------------------------
# Pretty Print Table
# -----------------------------
print("\n")
print("=" * 90)
print(f"{'Classification Performance of SS-MixNet on ' + DATASET:^90}")
print("=" * 90)

print(f"{'Class':<25}{'Train':>8}{'Val':>8}{'Test':>10}{'Total':>10}{'Accuracy (%)':>15}")
print("-" * 90)

for i in range(len(class_name)):
    print(f"{df.iloc[i,0]:<25}"
          f"{df.iloc[i,1]:>8}"
          f"{df.iloc[i,2]:>8}"
          f"{df.iloc[i,3]:>10}"
          f"{df.iloc[i,4]:>10}"
          f"{df.iloc[i,5]:>15}")

print("-" * 90)

print(f"{'Overall Accuracy (OA)':<25}{'':>8}{'':>8}{'':>10}{'':>10}{round(oa*100,2):>15}")
print(f"{'Average Accuracy (AA)':<25}{'':>8}{'':>8}{'':>10}{'':>10}{round(aa*100,2):>15}")
print(f"{'Kappa (×100)':<25}{'':>8}{'':>8}{'':>10}{'':>10}{round(kappa*100,2):>15}")

print("=" * 90)
# Out:
# ==========================================================================================
#                   Classification Performance of SS-MixNet on Tangdaowan
# ==========================================================================================
# Class                       Train     Val      Test     Total   Accuracy (%)
# ------------------------------------------------------------------------------------------
# Rubber track                  904     388     24557     25849          99.92
# Flaggingv                    1945     833     52775     55553          99.71
# Sandy                        1191     511     32335     34037          98.76
# Asphalt                      2124     911     57655     60690          99.76
# Boardwalk                      65      28      1769      1862           97.4
# Rocky shallows               1299     557     35269     37125          97.87
# Grassland                     494     212     13421     14127          91.27
# Bulrush                      2243     961     60883     64087          99.95
# Gravel road                  1075     460     29160     30695          99.64
# Ligustrum vicaryi              62      27      1694      1783          95.34
# Coniferous pine               743     319     20174     21236          94.71
# Spiraea                        27      11       711       749          95.36
# Bare soil                      59      25      1602      1686          99.88
# Buxus sinica                   31      13       842       886          97.15
# Photinia serrulata            491     210     13319     14020           94.1
# Populus                      4931    2114    133859    140904          98.63
# Ulmus pumila L                343     147      9312      9802          94.94
# Seawater                     1480     634     40161     42275          100.0
# ------------------------------------------------------------------------------------------
# Overall Accuracy (OA)                                                  98.66
# Average Accuracy (AA)                                                  97.47
# Kappa (×100)                                                           98.47
# ==========================================================================================

# %%
def get_class_map(model, X, label, window_size):

    indexes = np.argwhere(label != None)

    indexes = [tuple(i) for i in indexes]

    preds = []

    for i in tqdm(range(0, len(indexes), 2000)):
        batch_idx = indexes[i:i+2000]

        patches = createImageCubes(X, batch_idx, window_size)

        y_pred = model.predict(patches, verbose=0)

        preds.append(y_pred)

    preds = np.concatenate(preds)

    preds = np.argmax(preds, axis=1)

    Predicted_Class_Map = np.reshape(preds, label.shape)

    return Predicted_Class_Map

# %%
def img_display(data=None, rgb_band=None, classes=None, title=None, figsize=(7,7)):

    if data is not None:
        im_rgb = data[:,:,rgb_band]
        im_rgb = im_rgb / np.max(im_rgb) * 255
        im_rgb = np.asarray(im_rgb, np.uint8)

        plt.figure(figsize=figsize)
        plt.imshow(im_rgb)
        plt.title(title)
        plt.axis('off')
        plt.show()

    elif classes is not None:

        unique_classes = np.unique(classes)

        rgb_class = np.zeros((classes.shape[0], classes.shape[1], 3))

        colors = spectral.spy_colors

        for i in unique_classes:
            rgb_class[classes == i] = colors[i]

        rgb_class = np.asarray(rgb_class, np.uint8)

        plt.figure(figsize=figsize)
        plt.imshow(rgb_class)
        plt.title(title)
        plt.axis('off')
        plt.show()

# %%
model.load_weights(f"{DATASET}_SS_MixNet_CA.keras")

Predicted_Class_Map = get_class_map(model, data, gt, window_size)

img_display(classes=Predicted_Class_Map, title='Predicted')
# Out:
# 100%|██████████| 749/749 [11:03<00:00,  1.13it/s]

# %%
model.save("SS_MixNet_CA.keras")

from google.colab import files
files.download("SS_MixNet_CA.keras")

# %%
model.save_weights("SS_MixNet_CA_T4.weights.h5")

from google.colab import files
files.download("SS_MixNet_CA_T4.weights.h5")

# %%
import numpy as np

np.save("X_test_idx.npy", X_test_idx)
np.save("y_test.npy", y_test)

from google.colab import files
files.download("X_test_idx.npy")
files.download("y_test.npy")
