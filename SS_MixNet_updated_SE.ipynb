# %%
# !pip install spectral tqdm scikit-learn

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Requirement already satisfied: spectral in /usr/local/lib/python3.12/dist-packages (0.24)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from spectral) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import numpy as np
import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import scipy.io as sio
import spectral

from scipy.io import loadmat
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import minmax_scale
from sklearn.metrics import cohen_kappa_score, accuracy_score, confusion_matrix
from tensorflow.keras.layers import (
    Input,
    Conv3D,
    Conv2D,
    Dense,
    Dropout,
    Reshape,
    Permute,
    Add,
    Multiply,
    Activation,
    GlobalAveragePooling2D,
    GlobalMaxPooling2D,
    Concatenate,
    Lambda
)
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

# %%
def loadData(name):

    data_path = '/content/drive/MyDrive/datasets'

    if name == 'Tangdaowan':
        data = loadmat(os.path.join(data_path, 'QUH-Tangdaowan.mat'))['Tangdaowan']
        labels = loadmat(os.path.join(data_path, 'QUH-Tangdaowan_GT.mat'))['TangdaowanGT']
        class_name = [
            "Rubber track","Flaggingv","Sandy","Asphalt","Boardwalk",
            "Rocky shallows","Grassland","Bulrush","Gravel road",
            "Ligustrum vicaryi","Coniferous pine","Spiraea","Bare soil",
            "Buxus sinica","Photinia serrulata","Populus",
            "Ulmus pumila L","Seawater"
        ]

    elif name == 'Qingyun':
        data = loadmat(os.path.join(data_path, 'QUH-Qingyun.mat'))['Chengqu']
        labels = loadmat(os.path.join(data_path, 'QUH-Qingyun_GT.mat'))['ChengquGT']
        class_name = [
            "Trees","Concrete building","Car",
            "Ironhide building","Plastic playground","Asphalt road"
        ]

    elif name == 'Pingan':
        data = loadmat(os.path.join(data_path, 'QUH-Pingan.mat'))['Haigang']
        labels = loadmat(os.path.join(data_path, 'QUH-Pingan_GT.mat'))['HaigangGT']
        class_name = [
            "Ship","Seawater","Trees","Concrete structure building",
            "Floating pier","Asphalt road","Brick houses",
            "Steel houses","Wharf construction land","Car","Road"
        ]

    return data, labels, class_name


# ===========================
# PCA
# ===========================

def applyPCA(X, numComponents=15, normalization=True):

    newX = np.reshape(X, (-1, X.shape[2]))

    if numComponents != 0:
        pca = PCA(n_components=numComponents)
        newX = pca.fit_transform(newX)

    if normalization:
        newX = minmax_scale(newX, axis=1)

    newX = np.reshape(newX, (X.shape[0], X.shape[1], -1))

    return newX


def get_img_indexes(class_map, removeZeroindexes=True):

    if removeZeroindexes:
        indices = np.argwhere(class_map != 0)
    else:
        indices = np.argwhere(class_map != None)

    labels = class_map[indices[:, 0], indices[:, 1]]
    indices = [tuple(idx) for idx in indices]

    return indices, np.array(labels.tolist()) - 1


def createImageCubes(X, indices, windowSize):

    margin = windowSize // 2
    N, M, P = X.shape

    X_padded = np.zeros((N + 2 * margin, M + 2 * margin, P))
    X_padded[margin:N + margin, margin:M + margin, :] = X

    patches = []

    for idx in indices:
        i, j = idx
        i += margin
        j += margin

        patch = X_padded[i - margin:i + margin + 1,
                         j - margin:j + margin + 1, :]

        patches.append(patch)

    return np.array(patches)


# ===========================
# TRAIN TEST SPLIT
# ===========================

def splitTrainTestSet(X, y, testRatio):
    return train_test_split(
        X,
        y,
        test_size=testRatio,
        stratify=y,
        random_state=42   # FIXED SEED
    )


def predict_by_batching(model, input_tensor_idx, batch_size, X, windowSize):

    num_samples = len(input_tensor_idx)
    predictions = []

    for i in tqdm(range(0, num_samples, batch_size), desc="Predicting"):
        batch = createImageCubes(
            X, input_tensor_idx[i:i + batch_size], windowSize
        )

        batch = np.expand_dims(batch, axis=-1)
        batch_predictions = model.predict(batch, verbose=0)
        predictions.append(batch_predictions)

    return np.concatenate(predictions, axis=0)


# ===========================
# CLASS MAP GENERATION
# ===========================

def get_class_map(model, X, label, window_size):

    indexes, labels = get_img_indexes(label, removeZeroindexes=False)

    y_pred = predict_by_batching(model, indexes, 10000, X, window_size)
    y_pred = np.argmax(y_pred, axis=1).astype(np.uint8)

    return np.reshape(y_pred, label.shape) + 1


def img_display(data=None, rgb_band=None, classes=None,
                title=None, figsize=(7,7), palette=spectral.spy_colors):

    if data is not None:
        im_rgb = data[:, :, rgb_band]
        im_rgb = im_rgb / np.max(im_rgb) * 255
        im_rgb = np.asarray(im_rgb, np.uint8)

        plt.figure(figsize=figsize)
        plt.imshow(im_rgb)
        plt.title(title)
        plt.axis('off')

    elif classes is not None:
        rgb_class = np.zeros((classes.shape[0], classes.shape[1], 3))

        for i in np.unique(classes):
            rgb_class[classes == i] = palette[i]

        rgb_class = np.asarray(rgb_class, np.uint8)

        plt.figure(figsize=figsize)
        plt.imshow(rgb_class)
        plt.title(title)
        plt.axis('off')

# %%
DATASET = 'Tangdaowan'

data, gt, class_name = loadData(DATASET)

print("Original shape:", data.shape)
print("GT shape:", gt.shape)
print("Number of classes:", len(class_name))
# Out:
# Original shape: (1740, 860, 176)
# GT shape: (1740, 860)
# Number of classes: 18

# %%
data = applyPCA(data, numComponents=15, normalization=True)
data = data.astype(np.float32)

print("After PCA shape:", data.shape)
# Out:
# After PCA shape: (1740, 860, 15)

# %%
indexes, labels = get_img_indexes(gt, removeZeroindexes=True)

X_train_idx, X_test_idx, y_train, y_test = splitTrainTestSet(
    indexes, labels, testRatio=0.95)

X_train_idx, X_val_idx, y_train, y_val = splitTrainTestSet(
    X_train_idx, y_train, testRatio=0.30
)

print("Train samples:", len(y_train))
print("Val samples:", len(y_val))
print("Test samples:", len(y_test))
# Out:
# Train samples: 19507
# Val samples: 8361
# Test samples: 529498

# %%
window_size = 9

X_train = createImageCubes(data, X_train_idx, window_size)
X_val   = createImageCubes(data, X_val_idx, window_size)

print("Patch shape:", X_train.shape)
# Out:
# Patch shape: (19507, 9, 9, 15)

# %%
X_train = np.expand_dims(X_train, axis=-1)
X_val   = np.expand_dims(X_val, axis=-1)

print("New shape:", X_train.shape)
# Out:
# New shape: (19507, 9, 9, 15, 1)

# %%
import tensorflow as tf

y_train = tf.keras.utils.to_categorical(y_train)
y_val   = tf.keras.utils.to_categorical(y_val)

# %%
def spectral_mixer_block(x, hidden_dim, num_blocks=4):

    H, W, C, D = x.shape[1:]

    x = Permute((1, 2, 4, 3))(x)
    x = Reshape((H*W, D, C))(x)

    for _ in range(num_blocks):
        x1 = Dense(hidden_dim)(x)
        x1 = Dense(C)(x1)
        x = Add()([x, x1])

    return Reshape((H, W, C, D))(x)

# %%
def spatial_mixer_block(x, hidden_dim, num_blocks=4):

    H, W, C, D = x.shape[1:]

    x = Permute((3, 4, 1, 2))(x)
    x = Reshape((C, D, H*W))(x)

    for _ in range(num_blocks):
        x1 = Dense(hidden_dim)(x)
        x1 = Dense(H*W)(x1)
        x = Add()([x, x1])

    x = Permute((3, 1, 2))(x)
    return Reshape((H, W, C, D))(x)

# %%
# def dw_attention_block(x):

#     # Get static shape (allowed)
#     H, W, C, F = x.shape[1], x.shape[2], x.shape[3], x.shape[4]

#     # Reshape using Keras layer (NOT tf.reshape)
#     x_2D = Reshape((H, W, C * F))(x)

#     x_dw = DepthwiseConv2D(kernel_size=3, padding='same')(x_2D)
#     x_dw = Activation('sigmoid')(x_dw)

#     return Multiply()([x_2D, x_dw])

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Reshape, Dense, Multiply

def se_block(x, reduction=4):

    channels = x.shape[-1]

    se = GlobalAveragePooling2D()(x)
    se = Reshape((1,1,channels))(se)

    se = Dense(channels // reduction, activation='gelu')(se)
    se = Dense(channels, activation='sigmoid')(se)

    return Multiply()([x, se])

# %%
def SS_MixNet(img_list, mixer_dim=256, num_classes=len(class_name)):

    input_shape = img_list.shape[1:]
    inp = Input(shape=input_shape)

    # =================================================
    # 3D Convolution Backbone (Stronger Feature Extraction)
    # =================================================
    x = Conv3D(32, (3,3,3), padding='same', activation='gelu')(inp)
    x = Conv3D(64, (3,3,3), padding='same', activation='gelu')(x)

    # =================================================
    # Spectral & Spatial Mixers
    # =================================================
    x_spe = spectral_mixer_block(x, mixer_dim)
    x_spa = spatial_mixer_block(x, mixer_dim)

    # =================================================
    # Fusion (5D Tensor)
    # =================================================
    x = Concatenate(axis=4)([x_spe, x_spa])

    # =================================================
    # Convert 5D → 4D (B, H, W, C*F)
    # =================================================
    H = x.shape[1]
    W = x.shape[2]
    C = x.shape[3]
    F = x.shape[4]
    x = Reshape((H, W, C * F))(x)

    # =================================================
    # Channel Attention (SE Block)
    # =================================================
    x = se_block(x)

    # =================================================
    # Residual Boost Layer (Improved)
    # =================================================
    res = Conv2D(x.shape[-1], 1, padding='same', activation='gelu')(x)
    x = Add()([x, res])

    # =================================================
    # Classification Head
    # =================================================
    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.4)(x)

    # IMPORTANT: float32 for stability
    out = Dense(num_classes, activation='softmax', dtype='float32')(x)

    model = Model(inp, out)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
        metrics=['accuracy']
    )

    return model

# %%
model = SS_MixNet(X_train, mixer_dim=256)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 9, 9, 15,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d (Conv3D)     │ (None, 9, 9, 15,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_1 (Conv3D)   │ (None, 9, 9, 15,  │     55,360 │ conv3d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_1 (Permute) │ (None, 15, 64, 9, │          0 │ conv3d_1[0][0]    │
# │                     │ 9)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute (Permute)   │ (None, 9, 9, 64,  │          0 │ conv3d_1[0][0]    │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 15, 64,    │          0 │ permute_1[0][0]   │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 81, 64,    │          0 │ permute[0][0]     │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 15, 64,    │     20,992 │ reshape_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 81, 64,    │      4,096 │ reshape[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 15, 64,    │     20,817 │ dense_8[0][0]     │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 81, 64,    │      3,855 │ dense[0][0]       │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 15, 64,    │          0 │ reshape_2[0][0],  │
# │                     │ 81)               │            │ dense_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 81, 64,    │          0 │ reshape[0][0],    │
# │                     │ 15)               │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 15, 64,    │     20,992 │ add_4[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 81, 64,    │      4,096 │ add[0][0]         │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 15, 64,    │     20,817 │ dense_10[0][0]    │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 81, 64,    │      3,855 │ dense_2[0][0]     │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 15, 64,    │          0 │ add_4[0][0],      │
# │                     │ 81)               │            │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 81, 64,    │          0 │ add[0][0],        │
# │                     │ 15)               │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 15, 64,    │     20,992 │ add_5[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 81, 64,    │      4,096 │ add_1[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_13 (Dense)    │ (None, 15, 64,    │     20,817 │ dense_12[0][0]    │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 81, 64,    │      3,855 │ dense_4[0][0]     │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 15, 64,    │          0 │ add_5[0][0],      │
# │                     │ 81)               │            │ dense_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 81, 64,    │          0 │ add_1[0][0],      │
# │                     │ 15)               │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 15, 64,    │     20,992 │ add_6[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 81, 64,    │      4,096 │ add_2[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 15, 64,    │     20,817 │ dense_14[0][0]    │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 81, 64,    │      3,855 │ dense_6[0][0]     │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 15, 64,    │          0 │ add_6[0][0],      │
# │                     │ 81)               │            │ dense_15[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 81, 64,    │          0 │ add_2[0][0],      │
# │                     │ 15)               │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_2 (Permute) │ (None, 81, 15,    │          0 │ add_7[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 9, 9, 15,  │          0 │ add_3[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 9, 9, 15,  │          0 │ permute_2[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 9, 9, 15,  │          0 │ reshape_1[0][0],  │
# │ (Concatenate)       │ 128)              │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 9, 9,      │          0 │ concatenate[0][0] │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1920)      │          0 │ reshape_4[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_5 (Reshape) │ (None, 1, 1,      │          0 │ global_average_p… │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 1, 1, 480) │    922,080 │ reshape_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 1, 1,      │    923,520 │ dense_16[0][0]    │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 9, 9,      │          0 │ reshape_4[0][0],  │
# │                     │ 1920)             │            │ dense_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 9, 9,      │  3,688,320 │ multiply[0][0]    │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 9, 9,      │          0 │ multiply[0][0],   │
# │                     │ 1920)             │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1920)      │          0 │ add_8[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1920)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 18)        │     34,578 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,823,794 (22.22 MB)
#  Trainable params: 5,823,794 (22.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    f"{DATASET}_SS_MixNet.keras",
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False,
    verbose=1
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=8,
    min_lr=5e-5
)

early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=12,
    restore_best_weights=True
)

history = model.fit(
    X_train,
    y_train,
    epochs=60,
    batch_size=256,   # T4 optimized
    validation_data=(X_val, y_val),
    callbacks=[checkpoint, lr_callback, early_stop]
)
# Out:
# Epoch 1/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - accuracy: 0.4335 - loss: 1.9870
# Epoch 1: val_accuracy improved from -inf to 0.80553, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 89s 655ms/step - accuracy: 0.4356 - loss: 1.9809 - val_accuracy: 0.8055 - val_loss: 0.9005 - learning_rate: 3.0000e-04
# Epoch 2/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.8124 - loss: 0.8517
# Epoch 2: val_accuracy improved from 0.80553 to 0.85779, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 26s 337ms/step - accuracy: 0.8126 - loss: 0.8511 - val_accuracy: 0.8578 - val_loss: 0.7224 - learning_rate: 3.0000e-04
# Epoch 3/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - accuracy: 0.8818 - loss: 0.6740
# Epoch 3: val_accuracy improved from 0.85779 to 0.91843, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 323ms/step - accuracy: 0.8819 - loss: 0.6736 - val_accuracy: 0.9184 - val_loss: 0.5655 - learning_rate: 3.0000e-04
# Epoch 4/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9108 - loss: 0.5828
# Epoch 4: val_accuracy improved from 0.91843 to 0.93386, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 326ms/step - accuracy: 0.9109 - loss: 0.5827 - val_accuracy: 0.9339 - val_loss: 0.5237 - learning_rate: 3.0000e-04
# Epoch 5/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.9279 - loss: 0.5389
# Epoch 5: val_accuracy improved from 0.93386 to 0.93541, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 26s 333ms/step - accuracy: 0.9279 - loss: 0.5388 - val_accuracy: 0.9354 - val_loss: 0.5069 - learning_rate: 3.0000e-04
# Epoch 6/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9398 - loss: 0.5114
# Epoch 6: val_accuracy improved from 0.93541 to 0.95216, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 328ms/step - accuracy: 0.9398 - loss: 0.5113 - val_accuracy: 0.9522 - val_loss: 0.4795 - learning_rate: 3.0000e-04
# Epoch 7/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9507 - loss: 0.4864
# Epoch 7: val_accuracy did not improve from 0.95216
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9507 - loss: 0.4863 - val_accuracy: 0.9499 - val_loss: 0.4712 - learning_rate: 3.0000e-04
# Epoch 8/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9559 - loss: 0.4706
# Epoch 8: val_accuracy improved from 0.95216 to 0.95910, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 327ms/step - accuracy: 0.9560 - loss: 0.4705 - val_accuracy: 0.9591 - val_loss: 0.4485 - learning_rate: 3.0000e-04
# Epoch 9/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.9639 - loss: 0.4479
# Epoch 9: val_accuracy improved from 0.95910 to 0.96185, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 328ms/step - accuracy: 0.9639 - loss: 0.4480 - val_accuracy: 0.9618 - val_loss: 0.4456 - learning_rate: 3.0000e-04
# Epoch 10/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9637 - loss: 0.4487
# Epoch 10: val_accuracy improved from 0.96185 to 0.96496, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 326ms/step - accuracy: 0.9637 - loss: 0.4487 - val_accuracy: 0.9650 - val_loss: 0.4347 - learning_rate: 3.0000e-04
# Epoch 11/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9685 - loss: 0.4353
# Epoch 11: val_accuracy improved from 0.96496 to 0.96615, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 328ms/step - accuracy: 0.9685 - loss: 0.4353 - val_accuracy: 0.9662 - val_loss: 0.4346 - learning_rate: 3.0000e-04
# Epoch 12/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9707 - loss: 0.4290
# Epoch 12: val_accuracy improved from 0.96615 to 0.96783, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 327ms/step - accuracy: 0.9707 - loss: 0.4290 - val_accuracy: 0.9678 - val_loss: 0.4266 - learning_rate: 3.0000e-04
# Epoch 13/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9730 - loss: 0.4207
# Epoch 13: val_accuracy did not improve from 0.96783
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9729 - loss: 0.4207 - val_accuracy: 0.9652 - val_loss: 0.4296 - learning_rate: 3.0000e-04
# Epoch 14/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9706 - loss: 0.4217
# Epoch 14: val_accuracy improved from 0.96783 to 0.96878, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 326ms/step - accuracy: 0.9707 - loss: 0.4217 - val_accuracy: 0.9688 - val_loss: 0.4231 - learning_rate: 3.0000e-04
# Epoch 15/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9750 - loss: 0.4141
# Epoch 15: val_accuracy improved from 0.96878 to 0.97369, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 326ms/step - accuracy: 0.9750 - loss: 0.4141 - val_accuracy: 0.9737 - val_loss: 0.4105 - learning_rate: 3.0000e-04
# Epoch 16/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9801 - loss: 0.4058
# Epoch 16: val_accuracy did not improve from 0.97369
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 319ms/step - accuracy: 0.9801 - loss: 0.4058 - val_accuracy: 0.9712 - val_loss: 0.4169 - learning_rate: 3.0000e-04
# Epoch 17/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9807 - loss: 0.4007
# Epoch 17: val_accuracy did not improve from 0.97369
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 0.9807 - loss: 0.4008 - val_accuracy: 0.9727 - val_loss: 0.4111 - learning_rate: 3.0000e-04
# Epoch 18/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9809 - loss: 0.4010
# Epoch 18: val_accuracy improved from 0.97369 to 0.97668, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 326ms/step - accuracy: 0.9809 - loss: 0.4010 - val_accuracy: 0.9767 - val_loss: 0.4025 - learning_rate: 3.0000e-04
# Epoch 19/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9814 - loss: 0.3981
# Epoch 19: val_accuracy did not improve from 0.97668
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9814 - loss: 0.3981 - val_accuracy: 0.9758 - val_loss: 0.4043 - learning_rate: 3.0000e-04
# Epoch 20/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9832 - loss: 0.3902
# Epoch 20: val_accuracy improved from 0.97668 to 0.97847, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 326ms/step - accuracy: 0.9832 - loss: 0.3902 - val_accuracy: 0.9785 - val_loss: 0.3971 - learning_rate: 3.0000e-04
# Epoch 21/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9839 - loss: 0.3892
# Epoch 21: val_accuracy improved from 0.97847 to 0.97883, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 27s 347ms/step - accuracy: 0.9839 - loss: 0.3892 - val_accuracy: 0.9788 - val_loss: 0.3944 - learning_rate: 3.0000e-04
# Epoch 22/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9869 - loss: 0.3864
# Epoch 22: val_accuracy did not improve from 0.97883
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9869 - loss: 0.3864 - val_accuracy: 0.9788 - val_loss: 0.3975 - learning_rate: 3.0000e-04
# Epoch 23/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9874 - loss: 0.3838
# Epoch 23: val_accuracy improved from 0.97883 to 0.98003, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 328ms/step - accuracy: 0.9874 - loss: 0.3838 - val_accuracy: 0.9800 - val_loss: 0.3930 - learning_rate: 3.0000e-04
# Epoch 24/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9876 - loss: 0.3809
# Epoch 24: val_accuracy did not improve from 0.98003
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9876 - loss: 0.3809 - val_accuracy: 0.9794 - val_loss: 0.3910 - learning_rate: 3.0000e-04
# Epoch 25/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9878 - loss: 0.3812
# Epoch 25: val_accuracy did not improve from 0.98003
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 0.9878 - loss: 0.3812 - val_accuracy: 0.9793 - val_loss: 0.3936 - learning_rate: 3.0000e-04
# Epoch 26/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9891 - loss: 0.3776
# Epoch 26: val_accuracy improved from 0.98003 to 0.98122, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 325ms/step - accuracy: 0.9891 - loss: 0.3776 - val_accuracy: 0.9812 - val_loss: 0.3891 - learning_rate: 3.0000e-04
# Epoch 27/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9890 - loss: 0.3741
# Epoch 27: val_accuracy did not improve from 0.98122
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9890 - loss: 0.3741 - val_accuracy: 0.9812 - val_loss: 0.3878 - learning_rate: 3.0000e-04
# Epoch 28/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9897 - loss: 0.3739
# Epoch 28: val_accuracy improved from 0.98122 to 0.98194, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 327ms/step - accuracy: 0.9897 - loss: 0.3739 - val_accuracy: 0.9819 - val_loss: 0.3863 - learning_rate: 3.0000e-04
# Epoch 29/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9920 - loss: 0.3705
# Epoch 29: val_accuracy did not improve from 0.98194
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9920 - loss: 0.3705 - val_accuracy: 0.9803 - val_loss: 0.3877 - learning_rate: 3.0000e-04
# Epoch 30/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9922 - loss: 0.3689
# Epoch 30: val_accuracy did not improve from 0.98194
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9922 - loss: 0.3689 - val_accuracy: 0.9818 - val_loss: 0.3845 - learning_rate: 3.0000e-04
# Epoch 31/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9923 - loss: 0.3674
# Epoch 31: val_accuracy did not improve from 0.98194
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9923 - loss: 0.3674 - val_accuracy: 0.9819 - val_loss: 0.3839 - learning_rate: 3.0000e-04
# Epoch 32/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9931 - loss: 0.3668
# Epoch 32: val_accuracy did not improve from 0.98194
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9931 - loss: 0.3668 - val_accuracy: 0.9819 - val_loss: 0.3865 - learning_rate: 3.0000e-04
# Epoch 33/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9910 - loss: 0.3725
# Epoch 33: val_accuracy improved from 0.98194 to 0.98206, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 328ms/step - accuracy: 0.9910 - loss: 0.3725 - val_accuracy: 0.9821 - val_loss: 0.3821 - learning_rate: 3.0000e-04
# Epoch 34/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9927 - loss: 0.3649
# Epoch 34: val_accuracy improved from 0.98206 to 0.98433, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 325ms/step - accuracy: 0.9927 - loss: 0.3649 - val_accuracy: 0.9843 - val_loss: 0.3834 - learning_rate: 3.0000e-04
# Epoch 35/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9944 - loss: 0.3623
# Epoch 35: val_accuracy did not improve from 0.98433
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 0.9944 - loss: 0.3624 - val_accuracy: 0.9824 - val_loss: 0.3806 - learning_rate: 3.0000e-04
# Epoch 36/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9921 - loss: 0.3633
# Epoch 36: val_accuracy did not improve from 0.98433
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 0.9921 - loss: 0.3633 - val_accuracy: 0.9824 - val_loss: 0.3821 - learning_rate: 3.0000e-04
# Epoch 37/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9932 - loss: 0.3626
# Epoch 37: val_accuracy did not improve from 0.98433
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 0.9932 - loss: 0.3626 - val_accuracy: 0.9841 - val_loss: 0.3807 - learning_rate: 3.0000e-04
# Epoch 38/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9957 - loss: 0.3592
# Epoch 38: val_accuracy did not improve from 0.98433
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9957 - loss: 0.3592 - val_accuracy: 0.9812 - val_loss: 0.3824 - learning_rate: 3.0000e-04
# Epoch 39/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9946 - loss: 0.3612
# Epoch 39: val_accuracy did not improve from 0.98433
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 0.9946 - loss: 0.3612 - val_accuracy: 0.9839 - val_loss: 0.3780 - learning_rate: 3.0000e-04
# Epoch 40/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9933 - loss: 0.3621
# Epoch 40: val_accuracy did not improve from 0.98433
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 0.9933 - loss: 0.3621 - val_accuracy: 0.9818 - val_loss: 0.3796 - learning_rate: 3.0000e-04
# Epoch 41/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9952 - loss: 0.3588
# Epoch 41: val_accuracy did not improve from 0.98433
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 0.9952 - loss: 0.3588 - val_accuracy: 0.9835 - val_loss: 0.3789 - learning_rate: 3.0000e-04
# Epoch 42/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9960 - loss: 0.3552
# Epoch 42: val_accuracy improved from 0.98433 to 0.98481, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 327ms/step - accuracy: 0.9960 - loss: 0.3552 - val_accuracy: 0.9848 - val_loss: 0.3794 - learning_rate: 3.0000e-04
# Epoch 43/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9965 - loss: 0.3538
# Epoch 43: val_accuracy did not improve from 0.98481
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9965 - loss: 0.3538 - val_accuracy: 0.9842 - val_loss: 0.3765 - learning_rate: 3.0000e-04
# Epoch 44/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9968 - loss: 0.3528
# Epoch 44: val_accuracy did not improve from 0.98481
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 319ms/step - accuracy: 0.9968 - loss: 0.3528 - val_accuracy: 0.9829 - val_loss: 0.3804 - learning_rate: 3.0000e-04
# Epoch 45/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9954 - loss: 0.3539
# Epoch 45: val_accuracy did not improve from 0.98481
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9954 - loss: 0.3539 - val_accuracy: 0.9839 - val_loss: 0.3740 - learning_rate: 3.0000e-04
# Epoch 46/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9964 - loss: 0.3510
# Epoch 46: val_accuracy improved from 0.98481 to 0.98541, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 326ms/step - accuracy: 0.9964 - loss: 0.3510 - val_accuracy: 0.9854 - val_loss: 0.3747 - learning_rate: 3.0000e-04
# Epoch 47/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9974 - loss: 0.3509
# Epoch 47: val_accuracy did not improve from 0.98541
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 0.9974 - loss: 0.3509 - val_accuracy: 0.9831 - val_loss: 0.3762 - learning_rate: 3.0000e-04
# Epoch 48/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9965 - loss: 0.3513
# Epoch 48: val_accuracy did not improve from 0.98541
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 0.9965 - loss: 0.3513 - val_accuracy: 0.9847 - val_loss: 0.3794 - learning_rate: 3.0000e-04
# Epoch 49/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9954 - loss: 0.3543
# Epoch 49: val_accuracy did not improve from 0.98541
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 0.9954 - loss: 0.3543 - val_accuracy: 0.9843 - val_loss: 0.3776 - learning_rate: 3.0000e-04
# Epoch 50/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9963 - loss: 0.3520
# Epoch 50: val_accuracy did not improve from 0.98541
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 0.9963 - loss: 0.3520 - val_accuracy: 0.9848 - val_loss: 0.3735 - learning_rate: 3.0000e-04
# Epoch 51/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9973 - loss: 0.3477
# Epoch 51: val_accuracy improved from 0.98541 to 0.98601, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 326ms/step - accuracy: 0.9973 - loss: 0.3477 - val_accuracy: 0.9860 - val_loss: 0.3721 - learning_rate: 3.0000e-04
# Epoch 52/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.9971 - loss: 0.3484
# Epoch 52: val_accuracy improved from 0.98601 to 0.98648, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 328ms/step - accuracy: 0.9971 - loss: 0.3484 - val_accuracy: 0.9865 - val_loss: 0.3736 - learning_rate: 3.0000e-04
# Epoch 53/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9981 - loss: 0.3459
# Epoch 53: val_accuracy did not improve from 0.98648
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 0.9981 - loss: 0.3459 - val_accuracy: 0.9849 - val_loss: 0.3773 - learning_rate: 3.0000e-04
# Epoch 54/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9979 - loss: 0.3464
# Epoch 54: val_accuracy improved from 0.98648 to 0.98660, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 327ms/step - accuracy: 0.9979 - loss: 0.3464 - val_accuracy: 0.9866 - val_loss: 0.3722 - learning_rate: 3.0000e-04
# Epoch 55/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9979 - loss: 0.3463
# Epoch 55: val_accuracy did not improve from 0.98660
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9979 - loss: 0.3463 - val_accuracy: 0.9860 - val_loss: 0.3709 - learning_rate: 3.0000e-04
# Epoch 56/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.9979 - loss: 0.3449
# Epoch 56: val_accuracy did not improve from 0.98660
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9979 - loss: 0.3449 - val_accuracy: 0.9858 - val_loss: 0.3724 - learning_rate: 3.0000e-04
# Epoch 57/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9962 - loss: 0.3485
# Epoch 57: val_accuracy did not improve from 0.98660
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9962 - loss: 0.3485 - val_accuracy: 0.9854 - val_loss: 0.3756 - learning_rate: 3.0000e-04
# Epoch 58/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9976 - loss: 0.3462
# Epoch 58: val_accuracy did not improve from 0.98660
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 318ms/step - accuracy: 0.9976 - loss: 0.3463 - val_accuracy: 0.9864 - val_loss: 0.3729 - learning_rate: 3.0000e-04
# Epoch 59/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9983 - loss: 0.3447
# Epoch 59: val_accuracy improved from 0.98660 to 0.98708, saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 25s 325ms/step - accuracy: 0.9983 - loss: 0.3447 - val_accuracy: 0.9871 - val_loss: 0.3693 - learning_rate: 3.0000e-04
# Epoch 60/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9982 - loss: 0.3440
# Epoch 60: val_accuracy did not improve from 0.98708
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 24s 317ms/step - accuracy: 0.9982 - loss: 0.3440 - val_accuracy: 0.9845 - val_loss: 0.3735 - learning_rate: 3.0000e-04

# %%
Y_pred_test = predict_by_batching(
    model,
    input_tensor_idx=X_test_idx,
    batch_size=2000,   # T4 can handle larger batches for inference
    X=data,
    windowSize=window_size
)

y_pred_test = np.argmax(Y_pred_test, axis=1)

# ==============================
# Metrics
# ==============================

oa = accuracy_score(y_test, y_pred_test)
kappa = cohen_kappa_score(y_test, y_pred_test)

cm = confusion_matrix(y_test, y_pred_test)

# Safe class accuracy calculation
class_acc = np.zeros(cm.shape[0])
for i in range(cm.shape[0]):
    if cm.sum(axis=1)[i] != 0:
        class_acc[i] = cm[i, i] / cm.sum(axis=1)[i]

aa = np.mean(class_acc)

# ==============================
# Print Results
# ==============================

print("="*60)
print("Evaluation Results")
print("="*60)
print(f"Overall Accuracy (OA): {oa*100:.2f}%")
print(f"Average Accuracy (AA): {aa*100:.2f}%")
print(f"Kappa Coefficient: {kappa*100:.2f}")
print("="*60)
# Out:
# Predicting: 100%|██████████| 265/265 [05:12<00:00,  1.18s/it]
# ============================================================
# Evaluation Results
# ============================================================
# Overall Accuracy (OA): 98.53%
# Average Accuracy (AA): 96.91%
# Kappa Coefficient: 98.33
# ============================================================

# %%
import pandas as pd
import numpy as np

# -----------------------------
# Compute per-class accuracy
# -----------------------------
class_accuracy = cm.diagonal() / cm.sum(axis=1) * 100

rows = []

for i in range(len(class_name)):

    train_count = (y_train.argmax(axis=1) == i).sum()
    val_count   = (y_val.argmax(axis=1) == i).sum()
    test_count  = (y_test == i).sum()
    total_count = (gt == (i+1)).sum()

    rows.append([
        class_name[i],
        train_count,
        val_count,
        test_count,
        total_count,
        round(class_accuracy[i], 2)
    ])

# -----------------------------
# Create DataFrame
# -----------------------------
df = pd.DataFrame(
    rows,
    columns=[
        "Class",
        "Train",
        "Val",
        "Test",
        "Total",
        "SS-MixNet (%)"
    ]
)

# -----------------------------
# Summary Metrics
# -----------------------------
summary_rows = pd.DataFrame([
    ["OA (%)", "", "", "", "", round(oa * 100, 2)],
    ["AA (%)", "", "", "", "", round(aa * 100, 2)],
    ["Kappa (×100)", "", "", "", "", round(kappa * 100, 2)]
], columns=df.columns)

df_final = pd.concat([df, summary_rows], ignore_index=True)

# -----------------------------
# Pretty Print Table
# -----------------------------
print("\n")
print("=" * 90)
print(f"{'Classification Performance of SS-MixNet on ' + DATASET:^90}")
print("=" * 90)

print(f"{'Class':<25}{'Train':>8}{'Val':>8}{'Test':>10}{'Total':>10}{'Accuracy (%)':>15}")
print("-" * 90)

for i in range(len(class_name)):
    print(f"{df.iloc[i,0]:<25}"
          f"{df.iloc[i,1]:>8}"
          f"{df.iloc[i,2]:>8}"
          f"{df.iloc[i,3]:>10}"
          f"{df.iloc[i,4]:>10}"
          f"{df.iloc[i,5]:>15}")

print("-" * 90)

print(f"{'Overall Accuracy (OA)':<25}{'':>8}{'':>8}{'':>10}{'':>10}{round(oa*100,2):>15}")
print(f"{'Average Accuracy (AA)':<25}{'':>8}{'':>8}{'':>10}{'':>10}{round(aa*100,2):>15}")
print(f"{'Kappa (×100)':<25}{'':>8}{'':>8}{'':>10}{'':>10}{round(kappa*100,2):>15}")

print("=" * 90)
# Out:
# ==========================================================================================
#                   Classification Performance of SS-MixNet on Tangdaowan
# ==========================================================================================
# Class                       Train     Val      Test     Total   Accuracy (%)
# ------------------------------------------------------------------------------------------
# Rubber track                  904     388     24557     25849          99.95
# Flaggingv                    1945     833     52775     55553          99.66
# Sandy                        1191     511     32335     34037           98.1
# Asphalt                      2124     911     57655     60690          99.78
# Boardwalk                      65      28      1769      1862          96.95
# Rocky shallows               1299     557     35269     37125          97.71
# Grassland                     494     212     13421     14127          89.92
# Bulrush                      2243     961     60883     64087          100.0
# Gravel road                  1075     460     29160     30695          99.69
# Ligustrum vicaryi              62      27      1694      1783          93.86
# Coniferous pine               743     319     20174     21236          94.45
# Spiraea                        27      11       711       749          92.69
# Bare soil                      59      25      1602      1686          100.0
# Buxus sinica                   31      13       842       886          95.13
# Photinia serrulata            491     210     13319     14020          93.43
# Populus                      4931    2114    133859    140904          98.63
# Ulmus pumila L                343     147      9312      9802          94.41
# Seawater                     1480     634     40161     42275          100.0
# ------------------------------------------------------------------------------------------
# Overall Accuracy (OA)                                                  98.53
# Average Accuracy (AA)                                                  96.91
# Kappa (×100)                                                           98.33
# ==========================================================================================

# %%
model.load_weights(f"{DATASET}_SS_MixNet.keras")


Predicted_Class_Map = get_class_map(model, data, gt, window_size)

img_display(classes=Predicted_Class_Map, title='Predicted')
# Out:
# Predicting: 100%|██████████| 150/150 [12:23<00:00,  4.96s/it]

# %%
model.save("SS_MixNet_Updated_new.keras")

# %%
from google.colab import files
files.download("SS_MixNet_Updated_new.keras")

# %%
import numpy as np

np.save("X_test_idx.npy", X_test_idx)
np.save("y_test.npy", y_test)

files.download("X_test_idx.npy")
files.download("y_test.npy")

# %%
model.save_weights("SS_MixNet_Updated_new.weights.h5")
files.download("SS_MixNet_Updated_new.weights.h5")
