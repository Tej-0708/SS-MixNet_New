# %%
# !pip install spectral tqdm scikit-learn

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Collecting spectral
#   Downloading spectral-0.24-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from spectral) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Downloading spectral-0.24-py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.0/249.0 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: spectral
# Successfully installed spectral-0.24
# Mounted at /content/drive

# %%
import os
import numpy as np
import tensorflow as tf
from scipy.io import loadmat
from tqdm import tqdm
import matplotlib.pyplot as plt
import spectral

from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import minmax_scale
from sklearn.metrics import accuracy_score, confusion_matrix, cohen_kappa_score

from tensorflow.keras.layers import (
    Input, Conv3D, Conv2D, Dense, Dropout, Reshape,
    Concatenate, Add, GlobalAveragePooling2D,
    Permute, Multiply, Conv1D
)
from tensorflow.keras.models import Model

# %%
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

print("Mixed precision policy:", mixed_precision.global_policy())
# Out:
# Mixed precision policy: <DTypePolicy "mixed_float16">

# %%
def loadData(name):

    data_path = '/content/drive/MyDrive/datasets'

    if name == 'Tangdaowan':
        data = loadmat(os.path.join(data_path, 'QUH-Tangdaowan.mat'))['Tangdaowan']
        labels = loadmat(os.path.join(data_path, 'QUH-Tangdaowan_GT.mat'))['TangdaowanGT']
        class_name = [
            "Rubber track","Flaggingv","Sandy","Asphalt","Boardwalk",
            "Rocky shallows","Grassland","Bulrush","Gravel road",
            "Ligustrum vicaryi","Coniferous pine","Spiraea","Bare soil",
            "Buxus sinica","Photinia serrulata","Populus",
            "Ulmus pumila L","Seawater"
        ]

    elif name == 'Qingyun':
        data = loadmat(os.path.join(data_path, 'QUH-Qingyun.mat'))['Chengqu']
        labels = loadmat(os.path.join(data_path, 'QUH-Qingyun_GT.mat'))['ChengquGT']
        class_name = [
            "Trees","Concrete building","Car",
            "Ironhide building","Plastic playground","Asphalt road"
        ]

    elif name == 'Pingan':
        data = loadmat(os.path.join(data_path, 'QUH-Pingan.mat'))['Haigang']
        labels = loadmat(os.path.join(data_path, 'QUH-Pingan_GT.mat'))['HaigangGT']
        class_name = [
            "Ship","Seawater","Trees","Concrete structure building",
            "Floating pier","Asphalt road","Brick houses",
            "Steel houses","Wharf construction land","Car","Road"
        ]

    return data, labels, class_name

# %%
def applyPCA(X, numComponents=15):

    newX = np.reshape(X, (-1, X.shape[2]))

    pca = PCA(n_components=numComponents)
    newX = pca.fit_transform(newX)

    newX = minmax_scale(newX, axis=1)

    newX = np.reshape(newX, (X.shape[0], X.shape[1], numComponents))

    return newX

# %%
def createImageCubes(X, indices, windowSize):

    margin = windowSize // 2
    N, M, P = X.shape

    X_padded = np.zeros((N+2*margin, M+2*margin, P))
    X_padded[margin:N+margin, margin:M+margin, :] = X

    patches = []

    for idx in indices:
        i,j = idx
        i += margin
        j += margin

        patch = X_padded[i-margin:i+margin+1, j-margin:j+margin+1, :]
        patches.append(patch)

    patches = np.array(patches)
    patches = patches[..., np.newaxis]  # needed for Conv3D

    return patches

# %%
def get_img_indexes(class_map, removeZeroindexes=True):

    if removeZeroindexes:
        indices = np.argwhere(class_map != 0)
    else:
        indices = np.argwhere(class_map != None)

    labels = class_map[indices[:,0], indices[:,1]]
    indices = [tuple(i) for i in indices]

    return indices, np.array(labels.tolist())-1

# %%
def splitTrainTestSet(X, y, testRatio):

    return train_test_split(
        X,
        y,
        test_size=testRatio,
        stratify=y,
        random_state=42
    )

# %%
def spectral_mixer_block(x, hidden_dim, num_blocks=2):

    H,W,C,D = x.shape[1:]

    x = Permute((1,2,4,3))(x)
    x = Reshape((H*W, D, C))(x)

    for _ in range(num_blocks):
        x1 = Dense(hidden_dim, activation='gelu')(x)
        x1 = Dense(C)(x1)
        x = Add()([x,x1])

    return Reshape((H,W,C,D))(x)

# %%
def spatial_mixer_block(x, hidden_dim, num_blocks=2):

    H,W,C,D = x.shape[1:]

    x = Permute((3,4,1,2))(x)
    x = Reshape((C,D,H*W))(x)

    for _ in range(num_blocks):
        x1 = Dense(hidden_dim, activation='gelu')(x)
        x1 = Dense(H*W)(x1)
        x = Add()([x,x1])

    x = Permute((3,1,2))(x)

    return Reshape((H,W,C,D))(x)

# %%
def eca_block(x, k_size=3):

    channels = x.shape[-1]

    y = GlobalAveragePooling2D()(x)
    y = Reshape((channels,1))(y)

    y = Conv1D(1, kernel_size=k_size, padding='same', use_bias=False)(y)
    y = tf.keras.activations.sigmoid(y)

    y = Reshape((1,1,channels))(y)

    return Multiply()([x,y])

# %%
def SS_MixNet(img_list, num_classes, mixer_dim=256):

    input_shape = img_list.shape[1:]
    inp = Input(shape=input_shape)

    x = Conv3D(32,(3,3,3),padding='same',activation='gelu')(inp)
    x = Conv3D(64,(3,3,3),padding='same',activation='gelu')(x)

    x_spe = spectral_mixer_block(x,mixer_dim)
    x_spa = spatial_mixer_block(x,mixer_dim)

    x = Concatenate(axis=4)([x_spe,x_spa])

    H,W,C,F = x.shape[1:]
    x = Reshape((H,W,C*F))(x)

    x = eca_block(x)

    res = Conv2D(x.shape[-1],1,padding='same',activation='gelu')(x)
    x = Add()([x,res])

    x = GlobalAveragePooling2D()(x)
    x = Dropout(0.4)(x)

    out = Dense(num_classes,activation='softmax',dtype='float32')(x)

    model = Model(inp,out)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
        metrics=['accuracy']
    )

    return model

# %%
DATASET='Tangdaowan'

data,gt,class_name = loadData(DATASET)

print("Data shape:",data.shape)
# Out:
# Data shape: (1740, 860, 176)

# %%
data = applyPCA(data, numComponents=15)

# %%
indexes,labels = get_img_indexes(gt)

X_train_idx,X_test_idx,y_train,y_test = splitTrainTestSet(indexes,labels,0.95)
X_train_idx,X_val_idx,y_train,y_val = splitTrainTestSet(X_train_idx,y_train,0.30)

# %%
window_size=9

X_train=createImageCubes(data,X_train_idx,window_size)
X_val=createImageCubes(data,X_val_idx,window_size)

y_train=tf.keras.utils.to_categorical(y_train)
y_val=tf.keras.utils.to_categorical(y_val)

# %%
model = SS_MixNet(
    X_train,
    num_classes=len(class_name),
    mixer_dim=256
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 9, 9, 15,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d (Conv3D)     │ (None, 9, 9, 15,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_1 (Conv3D)   │ (None, 9, 9, 15,  │     55,360 │ conv3d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_1 (Permute) │ (None, 15, 64, 9, │          0 │ conv3d_1[0][0]    │
# │                     │ 9)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute (Permute)   │ (None, 9, 9, 64,  │          0 │ conv3d_1[0][0]    │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 15, 64,    │          0 │ permute_1[0][0]   │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 81, 64,    │          0 │ permute[0][0]     │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 15, 64,    │     20,992 │ reshape_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 81, 64,    │      4,096 │ reshape[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 15, 64,    │     20,817 │ dense_4[0][0]     │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 81, 64,    │      3,855 │ dense[0][0]       │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 15, 64,    │          0 │ reshape_2[0][0],  │
# │                     │ 81)               │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 81, 64,    │          0 │ reshape[0][0],    │
# │                     │ 15)               │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 15, 64,    │     20,992 │ add_2[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 81, 64,    │      4,096 │ add[0][0]         │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 15, 64,    │     20,817 │ dense_6[0][0]     │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 81, 64,    │      3,855 │ dense_2[0][0]     │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 15, 64,    │          0 │ add_2[0][0],      │
# │                     │ 81)               │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 81, 64,    │          0 │ add[0][0],        │
# │                     │ 15)               │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_2 (Permute) │ (None, 81, 15,    │          0 │ add_3[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 9, 9, 15,  │          0 │ add_1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 9, 9, 15,  │          0 │ permute_2[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 9, 9, 15,  │          0 │ reshape_1[0][0],  │
# │ (Concatenate)       │ 128)              │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 9, 9,      │          0 │ concatenate[0][0] │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1920)      │          0 │ reshape_4[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_5 (Reshape) │ (None, 1920, 1)   │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 1920, 1)   │          3 │ reshape_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sigmoid (Sigmoid)   │ (None, 1920, 1)   │          0 │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_6 (Reshape) │ (None, 1, 1,      │          0 │ sigmoid[0][0]     │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 9, 9,      │          0 │ reshape_4[0][0],  │
# │                     │ 1920)             │            │ reshape_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 9, 9,      │  3,688,320 │ multiply[0][0]    │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 9, 9,      │          0 │ multiply[0][0],   │
# │                     │ 1920)             │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1920)      │          0 │ add_4[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1920)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 18)        │     34,578 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,878,677 (14.80 MB)
#  Trainable params: 3,878,677 (14.80 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
checkpoint=tf.keras.callbacks.ModelCheckpoint(
    f"{DATASET}_SS_MixNet.keras",
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

lr_callback=tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=8,
    min_lr=5e-5
)

early_stop=tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=12,
    restore_best_weights=True
)

history=model.fit(
    X_train,
    y_train,
    epochs=60,
    batch_size=256,
    validation_data=(X_val,y_val),
    callbacks=[checkpoint,lr_callback,early_stop]
)
# Out:
# Epoch 1/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.3881 - loss: 2.1609
# Epoch 1: val_accuracy improved from None to 0.69669, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 1: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 73s 514ms/step - accuracy: 0.5225 - loss: 1.7403 - val_accuracy: 0.6967 - val_loss: 1.2029 - learning_rate: 3.0000e-04
# Epoch 2/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.7251 - loss: 1.1193
# Epoch 2: val_accuracy improved from 0.69669 to 0.80397, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 2: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 17s 221ms/step - accuracy: 0.7544 - loss: 1.0243 - val_accuracy: 0.8040 - val_loss: 0.8758 - learning_rate: 3.0000e-04
# Epoch 3/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.7966 - loss: 0.8919
# Epoch 3: val_accuracy improved from 0.80397 to 0.83949, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 3: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 237ms/step - accuracy: 0.8106 - loss: 0.8534 - val_accuracy: 0.8395 - val_loss: 0.7939 - learning_rate: 3.0000e-04
# Epoch 4/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.8313 - loss: 0.7860
# Epoch 4: val_accuracy improved from 0.83949 to 0.86054, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 4: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 253ms/step - accuracy: 0.8400 - loss: 0.7726 - val_accuracy: 0.8605 - val_loss: 0.7101 - learning_rate: 3.0000e-04
# Epoch 5/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.8525 - loss: 0.7248
# Epoch 5: val_accuracy improved from 0.86054 to 0.87561, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 5: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 237ms/step - accuracy: 0.8615 - loss: 0.7106 - val_accuracy: 0.8756 - val_loss: 0.6559 - learning_rate: 3.0000e-04
# Epoch 6/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - accuracy: 0.8771 - loss: 0.6741
# Epoch 6: val_accuracy improved from 0.87561 to 0.90504, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 6: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 230ms/step - accuracy: 0.8821 - loss: 0.6623 - val_accuracy: 0.9050 - val_loss: 0.6112 - learning_rate: 3.0000e-04
# Epoch 7/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 0.9013 - loss: 0.6244
# Epoch 7: val_accuracy improved from 0.90504 to 0.92034, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 7: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 234ms/step - accuracy: 0.9028 - loss: 0.6178 - val_accuracy: 0.9203 - val_loss: 0.5739 - learning_rate: 3.0000e-04
# Epoch 8/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9084 - loss: 0.6008
# Epoch 8: val_accuracy improved from 0.92034 to 0.92955, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 8: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 241ms/step - accuracy: 0.9134 - loss: 0.5888 - val_accuracy: 0.9296 - val_loss: 0.5523 - learning_rate: 3.0000e-04
# Epoch 9/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.9228 - loss: 0.5625
# Epoch 9: val_accuracy improved from 0.92955 to 0.94044, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 9: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 242ms/step - accuracy: 0.9243 - loss: 0.5578 - val_accuracy: 0.9404 - val_loss: 0.5205 - learning_rate: 3.0000e-04
# Epoch 10/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9279 - loss: 0.5419
# Epoch 10: val_accuracy improved from 0.94044 to 0.94498, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 10: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 238ms/step - accuracy: 0.9307 - loss: 0.5363 - val_accuracy: 0.9450 - val_loss: 0.5035 - learning_rate: 3.0000e-04
# Epoch 11/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step - accuracy: 0.9373 - loss: 0.5225
# Epoch 11: val_accuracy did not improve from 0.94498
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 230ms/step - accuracy: 0.9396 - loss: 0.5155 - val_accuracy: 0.9440 - val_loss: 0.4991 - learning_rate: 3.0000e-04
# Epoch 12/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9431 - loss: 0.5077
# Epoch 12: val_accuracy improved from 0.94498 to 0.95312, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 12: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 238ms/step - accuracy: 0.9458 - loss: 0.5007 - val_accuracy: 0.9531 - val_loss: 0.4763 - learning_rate: 3.0000e-04
# Epoch 13/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9510 - loss: 0.4896
# Epoch 13: val_accuracy improved from 0.95312 to 0.95503, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 13: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 239ms/step - accuracy: 0.9505 - loss: 0.4888 - val_accuracy: 0.9550 - val_loss: 0.4698 - learning_rate: 3.0000e-04
# Epoch 14/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.9543 - loss: 0.4776
# Epoch 14: val_accuracy improved from 0.95503 to 0.95754, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 14: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 241ms/step - accuracy: 0.9547 - loss: 0.4753 - val_accuracy: 0.9575 - val_loss: 0.4610 - learning_rate: 3.0000e-04
# Epoch 15/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9576 - loss: 0.4683
# Epoch 15: val_accuracy did not improve from 0.95754
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 234ms/step - accuracy: 0.9573 - loss: 0.4686 - val_accuracy: 0.9553 - val_loss: 0.4657 - learning_rate: 3.0000e-04
# Epoch 16/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9594 - loss: 0.4638
# Epoch 16: val_accuracy improved from 0.95754 to 0.95898, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 16: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 239ms/step - accuracy: 0.9604 - loss: 0.4607 - val_accuracy: 0.9590 - val_loss: 0.4552 - learning_rate: 3.0000e-04
# Epoch 17/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9624 - loss: 0.4517
# Epoch 17: val_accuracy improved from 0.95898 to 0.96328, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 17: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9630 - loss: 0.4510 - val_accuracy: 0.9633 - val_loss: 0.4523 - learning_rate: 3.0000e-04
# Epoch 18/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9636 - loss: 0.4485
# Epoch 18: val_accuracy improved from 0.96328 to 0.96460, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 18: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 239ms/step - accuracy: 0.9638 - loss: 0.4467 - val_accuracy: 0.9646 - val_loss: 0.4370 - learning_rate: 3.0000e-04
# Epoch 19/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9639 - loss: 0.4477
# Epoch 19: val_accuracy improved from 0.96460 to 0.96986, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 19: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 239ms/step - accuracy: 0.9671 - loss: 0.4412 - val_accuracy: 0.9699 - val_loss: 0.4313 - learning_rate: 3.0000e-04
# Epoch 20/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9671 - loss: 0.4408
# Epoch 20: val_accuracy did not improve from 0.96986
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 234ms/step - accuracy: 0.9676 - loss: 0.4374 - val_accuracy: 0.9691 - val_loss: 0.4279 - learning_rate: 3.0000e-04
# Epoch 21/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9683 - loss: 0.4309
# Epoch 21: val_accuracy improved from 0.96986 to 0.97225, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 21: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9704 - loss: 0.4283 - val_accuracy: 0.9723 - val_loss: 0.4251 - learning_rate: 3.0000e-04
# Epoch 22/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9758 - loss: 0.4201
# Epoch 22: val_accuracy did not improve from 0.97225
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - accuracy: 0.9738 - loss: 0.4210 - val_accuracy: 0.9706 - val_loss: 0.4221 - learning_rate: 3.0000e-04
# Epoch 23/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9747 - loss: 0.4211
# Epoch 23: val_accuracy improved from 0.97225 to 0.97237, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 23: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9743 - loss: 0.4199 - val_accuracy: 0.9724 - val_loss: 0.4189 - learning_rate: 3.0000e-04
# Epoch 24/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9756 - loss: 0.4153
# Epoch 24: val_accuracy improved from 0.97237 to 0.97297, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 24: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 238ms/step - accuracy: 0.9745 - loss: 0.4173 - val_accuracy: 0.9730 - val_loss: 0.4177 - learning_rate: 3.0000e-04
# Epoch 25/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9755 - loss: 0.4151
# Epoch 25: val_accuracy improved from 0.97297 to 0.97357, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 25: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 236ms/step - accuracy: 0.9760 - loss: 0.4141 - val_accuracy: 0.9736 - val_loss: 0.4173 - learning_rate: 3.0000e-04
# Epoch 26/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9753 - loss: 0.4133
# Epoch 26: val_accuracy did not improve from 0.97357
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 232ms/step - accuracy: 0.9767 - loss: 0.4097 - val_accuracy: 0.9733 - val_loss: 0.4149 - learning_rate: 3.0000e-04
# Epoch 27/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9801 - loss: 0.4040
# Epoch 27: val_accuracy improved from 0.97357 to 0.97464, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 27: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 238ms/step - accuracy: 0.9799 - loss: 0.4049 - val_accuracy: 0.9746 - val_loss: 0.4106 - learning_rate: 3.0000e-04
# Epoch 28/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9777 - loss: 0.4045
# Epoch 28: val_accuracy improved from 0.97464 to 0.97668, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 28: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 238ms/step - accuracy: 0.9788 - loss: 0.4036 - val_accuracy: 0.9767 - val_loss: 0.4060 - learning_rate: 3.0000e-04
# Epoch 29/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9818 - loss: 0.4012
# Epoch 29: val_accuracy improved from 0.97668 to 0.97680, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 29: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9813 - loss: 0.4011 - val_accuracy: 0.9768 - val_loss: 0.4054 - learning_rate: 3.0000e-04
# Epoch 30/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9832 - loss: 0.3970
# Epoch 30: val_accuracy did not improve from 0.97680
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 234ms/step - accuracy: 0.9819 - loss: 0.3980 - val_accuracy: 0.9767 - val_loss: 0.4037 - learning_rate: 3.0000e-04
# Epoch 31/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9846 - loss: 0.3942
# Epoch 31: val_accuracy improved from 0.97680 to 0.97883, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 31: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 239ms/step - accuracy: 0.9831 - loss: 0.3961 - val_accuracy: 0.9788 - val_loss: 0.3985 - learning_rate: 3.0000e-04
# Epoch 32/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9840 - loss: 0.3957
# Epoch 32: val_accuracy did not improve from 0.97883
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 232ms/step - accuracy: 0.9839 - loss: 0.3951 - val_accuracy: 0.9772 - val_loss: 0.3995 - learning_rate: 3.0000e-04
# Epoch 33/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9859 - loss: 0.3887
# Epoch 33: val_accuracy did not improve from 0.97883
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - accuracy: 0.9855 - loss: 0.3889 - val_accuracy: 0.9773 - val_loss: 0.4010 - learning_rate: 3.0000e-04
# Epoch 34/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9864 - loss: 0.3867
# Epoch 34: val_accuracy did not improve from 0.97883
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 232ms/step - accuracy: 0.9861 - loss: 0.3872 - val_accuracy: 0.9781 - val_loss: 0.3968 - learning_rate: 3.0000e-04
# Epoch 35/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9884 - loss: 0.3835
# Epoch 35: val_accuracy did not improve from 0.97883
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 232ms/step - accuracy: 0.9869 - loss: 0.3852 - val_accuracy: 0.9774 - val_loss: 0.3977 - learning_rate: 3.0000e-04
# Epoch 36/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9878 - loss: 0.3834
# Epoch 36: val_accuracy improved from 0.97883 to 0.98003, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 36: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 237ms/step - accuracy: 0.9879 - loss: 0.3834 - val_accuracy: 0.9800 - val_loss: 0.3954 - learning_rate: 3.0000e-04
# Epoch 37/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9881 - loss: 0.3833
# Epoch 37: val_accuracy did not improve from 0.98003
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 231ms/step - accuracy: 0.9880 - loss: 0.3831 - val_accuracy: 0.9791 - val_loss: 0.3938 - learning_rate: 3.0000e-04
# Epoch 38/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9888 - loss: 0.3815
# Epoch 38: val_accuracy improved from 0.98003 to 0.98074, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 38: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 238ms/step - accuracy: 0.9887 - loss: 0.3807 - val_accuracy: 0.9807 - val_loss: 0.3922 - learning_rate: 3.0000e-04
# Epoch 39/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9900 - loss: 0.3766
# Epoch 39: val_accuracy did not improve from 0.98074
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - accuracy: 0.9901 - loss: 0.3769 - val_accuracy: 0.9804 - val_loss: 0.3906 - learning_rate: 3.0000e-04
# Epoch 40/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9904 - loss: 0.3762
# Epoch 40: val_accuracy did not improve from 0.98074
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 232ms/step - accuracy: 0.9895 - loss: 0.3768 - val_accuracy: 0.9806 - val_loss: 0.3914 - learning_rate: 3.0000e-04
# Epoch 41/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9902 - loss: 0.3774
# Epoch 41: val_accuracy did not improve from 0.98074
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - accuracy: 0.9900 - loss: 0.3774 - val_accuracy: 0.9788 - val_loss: 0.3902 - learning_rate: 3.0000e-04
# Epoch 42/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9924 - loss: 0.3719
# Epoch 42: val_accuracy improved from 0.98074 to 0.98254, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 42: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 240ms/step - accuracy: 0.9917 - loss: 0.3726 - val_accuracy: 0.9825 - val_loss: 0.3887 - learning_rate: 3.0000e-04
# Epoch 43/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9926 - loss: 0.3704
# Epoch 43: val_accuracy did not improve from 0.98254
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - accuracy: 0.9920 - loss: 0.3715 - val_accuracy: 0.9804 - val_loss: 0.3870 - learning_rate: 3.0000e-04
# Epoch 44/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9905 - loss: 0.3729
# Epoch 44: val_accuracy did not improve from 0.98254
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 232ms/step - accuracy: 0.9907 - loss: 0.3724 - val_accuracy: 0.9817 - val_loss: 0.3858 - learning_rate: 3.0000e-04
# Epoch 45/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9924 - loss: 0.3695
# Epoch 45: val_accuracy did not improve from 0.98254
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 232ms/step - accuracy: 0.9920 - loss: 0.3700 - val_accuracy: 0.9807 - val_loss: 0.3894 - learning_rate: 3.0000e-04
# Epoch 46/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9928 - loss: 0.3683
# Epoch 46: val_accuracy did not improve from 0.98254
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 232ms/step - accuracy: 0.9928 - loss: 0.3675 - val_accuracy: 0.9807 - val_loss: 0.3875 - learning_rate: 3.0000e-04
# Epoch 47/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9912 - loss: 0.3718
# Epoch 47: val_accuracy did not improve from 0.98254
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 231ms/step - accuracy: 0.9913 - loss: 0.3707 - val_accuracy: 0.9818 - val_loss: 0.3823 - learning_rate: 3.0000e-04
# Epoch 48/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9925 - loss: 0.3693
# Epoch 48: val_accuracy did not improve from 0.98254
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 231ms/step - accuracy: 0.9927 - loss: 0.3677 - val_accuracy: 0.9812 - val_loss: 0.3857 - learning_rate: 3.0000e-04
# Epoch 49/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9933 - loss: 0.3649
# Epoch 49: val_accuracy improved from 0.98254 to 0.98445, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 49: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 237ms/step - accuracy: 0.9934 - loss: 0.3651 - val_accuracy: 0.9845 - val_loss: 0.3814 - learning_rate: 3.0000e-04
# Epoch 50/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9939 - loss: 0.3639
# Epoch 50: val_accuracy did not improve from 0.98445
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 231ms/step - accuracy: 0.9938 - loss: 0.3645 - val_accuracy: 0.9831 - val_loss: 0.3841 - learning_rate: 3.0000e-04
# Epoch 51/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9946 - loss: 0.3644
# Epoch 51: val_accuracy did not improve from 0.98445
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 232ms/step - accuracy: 0.9944 - loss: 0.3633 - val_accuracy: 0.9810 - val_loss: 0.3835 - learning_rate: 3.0000e-04
# Epoch 52/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - accuracy: 0.9950 - loss: 0.3615
# Epoch 52: val_accuracy did not improve from 0.98445
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 233ms/step - accuracy: 0.9942 - loss: 0.3626 - val_accuracy: 0.9825 - val_loss: 0.3819 - learning_rate: 3.0000e-04
# Epoch 53/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9952 - loss: 0.3601
# Epoch 53: val_accuracy improved from 0.98445 to 0.98493, saving model to Tangdaowan_SS_MixNet.keras
#
# Epoch 53: finished saving model to Tangdaowan_SS_MixNet.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 239ms/step - accuracy: 0.9949 - loss: 0.3608 - val_accuracy: 0.9849 - val_loss: 0.3791 - learning_rate: 3.0000e-04
# Epoch 54/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9958 - loss: 0.3595
# Epoch 54: val_accuracy did not improve from 0.98493
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 234ms/step - accuracy: 0.9951 - loss: 0.3607 - val_accuracy: 0.9825 - val_loss: 0.3812 - learning_rate: 3.0000e-04
# Epoch 55/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9951 - loss: 0.3593
# Epoch 55: val_accuracy did not improve from 0.98493
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 234ms/step - accuracy: 0.9953 - loss: 0.3594 - val_accuracy: 0.9830 - val_loss: 0.3785 - learning_rate: 3.0000e-04
# Epoch 56/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9949 - loss: 0.3599
# Epoch 56: val_accuracy did not improve from 0.98493
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 234ms/step - accuracy: 0.9951 - loss: 0.3598 - val_accuracy: 0.9834 - val_loss: 0.3795 - learning_rate: 3.0000e-04
# Epoch 57/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9932 - loss: 0.3628
# Epoch 57: val_accuracy did not improve from 0.98493
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 234ms/step - accuracy: 0.9945 - loss: 0.3598 - val_accuracy: 0.9848 - val_loss: 0.3768 - learning_rate: 3.0000e-04
# Epoch 58/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9962 - loss: 0.3563
# Epoch 58: val_accuracy did not improve from 0.98493
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 234ms/step - accuracy: 0.9963 - loss: 0.3562 - val_accuracy: 0.9829 - val_loss: 0.3768 - learning_rate: 3.0000e-04
# Epoch 59/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9970 - loss: 0.3543
# Epoch 59: val_accuracy did not improve from 0.98493
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 231ms/step - accuracy: 0.9969 - loss: 0.3551 - val_accuracy: 0.9845 - val_loss: 0.3769 - learning_rate: 3.0000e-04
# Epoch 60/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.9976 - loss: 0.3537
# Epoch 60: val_accuracy did not improve from 0.98493
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 18s 234ms/step - accuracy: 0.9967 - loss: 0.3549 - val_accuracy: 0.9833 - val_loss: 0.3790 - learning_rate: 3.0000e-04

# %%
import pickle

with open("training_history.pkl", "wb") as f:
    pickle.dump(history.history, f)

print("Training history saved.")
# Out:
# Training history saved.

# %%
from google.colab import files

files.download("training_history.pkl")

# %%
import numpy as np

np.save("training_history.npy", history.history)

print("Training history saved as training_history.npy")
# Out:
# Training history saved as training_history.npy

# %%
from google.colab import files
files.download("training_history.npy")

# %%
import seaborn as sns

# %%
plt.figure(figsize=(7,5))

plt.plot(history.history['loss'], label="Train Loss")
plt.plot(history.history['val_loss'], label="Validation Loss")

plt.title("Epoch vs Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.legend()
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.plot(history.history['accuracy'], label="Train Accuracy")
plt.plot(history.history['val_accuracy'], label="Validation Accuracy")

plt.title("Epoch vs Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.legend()
plt.grid(True)

plt.show()

# %%
def predict_by_batching(model, idx, batch_size, X, windowSize):

    preds=[]

    for i in tqdm(range(0,len(idx),batch_size)):
        batch=createImageCubes(X,idx[i:i+batch_size],windowSize)
        preds.append(model.predict(batch,verbose=0))

    return np.concatenate(preds)

# %%
Y_pred_test=predict_by_batching(model,X_test_idx,2000,data,window_size)

y_pred_test=np.argmax(Y_pred_test,axis=1)

oa=accuracy_score(y_test,y_pred_test)
kappa=cohen_kappa_score(y_test,y_pred_test)

cm=confusion_matrix(y_test,y_pred_test)

plt.figure(figsize=(8,6))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()

class_acc=cm.diagonal()/cm.sum(axis=1)
aa=np.mean(class_acc)

print("Overall Accuracy:",round(oa*100,2))
print("Average Accuracy:",round(aa*100,2))
print("Kappa:",round(kappa*100,2))
# Out:
# 100%|██████████| 265/265 [04:09<00:00,  1.06it/s]
# Overall Accuracy: 98.26
# Average Accuracy: 96.53
# Kappa: 98.01

# %%
import json

test_metrics = {
    "Overall Accuracy (OA)": float(oa),
    "Average Accuracy (AA)": float(aa),
    "Kappa Score": float(kappa)
}

with open("test_metrics.json", "w") as f:
    json.dump(test_metrics, f, indent=4)

print("Test metrics saved.")
# Out:
# Test metrics saved.

# %%
from google.colab import files

files.download("test_metrics.json")

# %%
import pandas as pd

cm_df = pd.DataFrame(cm, index=class_name, columns=class_name)

cm_df.to_csv("confusion_matrix_test.csv")

print("Confusion matrix saved.")
# Out:
# Confusion matrix saved.

# %%
from google.colab import files

files.download("confusion_matrix_test.csv")

# %%
from sklearn.metrics import classification_report

# %%
print("\nClassification Report:\n")

print(
    classification_report(
        y_test,
        y_pred_test,
        target_names=class_name,
        digits=4
    )
)
# Out:
# Classification Report:
#
#                     precision    recall  f1-score   support
#
#       Rubber track     0.9987    0.9990    0.9989     24557
#          Flaggingv     0.9929    0.9968    0.9949     52775
#              Sandy     0.9590    0.9798    0.9693     32335
#            Asphalt     0.9972    0.9968    0.9970     57655
#          Boardwalk     0.9971    0.9593    0.9778      1769
#     Rocky shallows     0.9736    0.9643    0.9689     35269
#          Grassland     0.9197    0.8845    0.9018     13421
#            Bulrush     0.9999    1.0000    0.9999     60883
#        Gravel road     0.9976    0.9962    0.9969     29160
#  Ligustrum vicaryi     0.9975    0.9445    0.9703      1694
#    Coniferous pine     0.9667    0.9412    0.9538     20174
#            Spiraea     0.9614    0.9100    0.9350       711
#          Bare soil     0.9956    1.0000    0.9978      1602
#       Buxus sinica     0.9512    0.9501    0.9507       842
# Photinia serrulata     0.9660    0.9212    0.9430     13319
#            Populus     0.9704    0.9828    0.9765    133859
#     Ulmus pumila L     0.9899    0.9498    0.9695      9312
#           Seawater     1.0000    1.0000    1.0000     40161
#
#           accuracy                         0.9826    529498
#          macro avg     0.9797    0.9653    0.9723    529498
#       weighted avg     0.9825    0.9826    0.9825    529498

# %%
import pandas as pd

report = classification_report(
    y_test,
    y_pred_test,
    target_names=class_name,
    output_dict=True
)

df_report = pd.DataFrame(report).transpose()

df_report.to_csv("classification_report.csv")

pd.DataFrame(cm).to_csv("confusion_matrix.csv")

print("Results saved.")
# Out:
# Results saved.

# %%
import pandas as pd

report_df = pd.DataFrame(report).transpose()

report_df.to_csv("classification_report.csv")

print("Classification report saved.")
# Out:
# Classification report saved.

# %%
from google.colab import files

files.download("classification_report.csv")

# %%
import pandas as pd
import numpy as np

# -----------------------------
# Compute per-class accuracy
# -----------------------------
class_accuracy = cm.diagonal() / cm.sum(axis=1) * 100

rows = []

for i in range(len(class_name)):

    train_count = (y_train.argmax(axis=1) == i).sum()
    val_count   = (y_val.argmax(axis=1) == i).sum()
    test_count  = (y_test == i).sum()
    total_count = (gt == (i+1)).sum()

    rows.append([
        class_name[i],
        train_count,
        val_count,
        test_count,
        total_count,
        round(class_accuracy[i], 2)
    ])

# -----------------------------
# Create DataFrame
# -----------------------------
df = pd.DataFrame(
    rows,
    columns=[
        "Class",
        "Train",
        "Val",
        "Test",
        "Total",
        "SS-MixNet (%)"
    ]
)

# -----------------------------
# Summary Metrics
# -----------------------------
summary_rows = pd.DataFrame([
    ["OA (%)", "", "", "", "", round(oa * 100, 2)],
    ["AA (%)", "", "", "", "", round(aa * 100, 2)],
    ["Kappa (×100)", "", "", "", "", round(kappa * 100, 2)]
], columns=df.columns)

df_final = pd.concat([df, summary_rows], ignore_index=True)

# -----------------------------
# Pretty Print Table
# -----------------------------
print("\n")
print("=" * 90)
print(f"{'Classification Performance of SS-MixNet on ' + DATASET:^90}")
print("=" * 90)

print(f"{'Class':<25}{'Train':>8}{'Val':>8}{'Test':>10}{'Total':>10}{'Accuracy (%)':>15}")
print("-" * 90)

for i in range(len(class_name)):
    print(f"{df.iloc[i,0]:<25}"
          f"{df.iloc[i,1]:>8}"
          f"{df.iloc[i,2]:>8}"
          f"{df.iloc[i,3]:>10}"
          f"{df.iloc[i,4]:>10}"
          f"{df.iloc[i,5]:>15}")

print("-" * 90)

print(f"{'Overall Accuracy (OA)':<25}{'':>8}{'':>8}{'':>10}{'':>10}{round(oa*100,2):>15}")
print(f"{'Average Accuracy (AA)':<25}{'':>8}{'':>8}{'':>10}{'':>10}{round(aa*100,2):>15}")
print(f"{'Kappa (×100)':<25}{'':>8}{'':>8}{'':>10}{'':>10}{round(kappa*100,2):>15}")

print("=" * 90)
# Out:
# ==========================================================================================
#                   Classification Performance of SS-MixNet on Tangdaowan
# ==========================================================================================
# Class                       Train     Val      Test     Total   Accuracy (%)
# ------------------------------------------------------------------------------------------
# Rubber track                  904     388     24557     25849           99.9
# Flaggingv                    1945     833     52775     55553          99.68
# Sandy                        1191     511     32335     34037          97.98
# Asphalt                      2124     911     57655     60690          99.68
# Boardwalk                      65      28      1769      1862          95.93
# Rocky shallows               1299     557     35269     37125          96.43
# Grassland                     494     212     13421     14127          88.45
# Bulrush                      2243     961     60883     64087          100.0
# Gravel road                  1075     460     29160     30695          99.62
# Ligustrum vicaryi              62      27      1694      1783          94.45
# Coniferous pine               743     319     20174     21236          94.12
# Spiraea                        27      11       711       749           91.0
# Bare soil                      59      25      1602      1686          100.0
# Buxus sinica                   31      13       842       886          95.01
# Photinia serrulata            491     210     13319     14020          92.12
# Populus                      4931    2114    133859    140904          98.28
# Ulmus pumila L                343     147      9312      9802          94.98
# Seawater                     1480     634     40161     42275          100.0
# ------------------------------------------------------------------------------------------
# Overall Accuracy (OA)                                                  98.26
# Average Accuracy (AA)                                                  96.53
# Kappa (×100)                                                           98.01
# ==========================================================================================

# %%
def get_class_map(model, X, label, window_size):

    indexes = np.argwhere(label != None)

    indexes = [tuple(i) for i in indexes]

    preds = []

    for i in tqdm(range(0, len(indexes), 2000)):
        batch_idx = indexes[i:i+2000]

        patches = createImageCubes(X, batch_idx, window_size)

        y_pred = model.predict(patches, verbose=0)

        preds.append(y_pred)

    preds = np.concatenate(preds)

    preds = np.argmax(preds, axis=1)

    Predicted_Class_Map = np.reshape(preds, label.shape)

    return Predicted_Class_Map

# %%
def img_display(data=None, rgb_band=None, classes=None, title=None, figsize=(7,7)):

    if data is not None:
        im_rgb = data[:,:,rgb_band]
        im_rgb = im_rgb / np.max(im_rgb) * 255
        im_rgb = np.asarray(im_rgb, np.uint8)

        plt.figure(figsize=figsize)
        plt.imshow(im_rgb)
        plt.title(title)
        plt.axis('off')
        plt.show()

    elif classes is not None:

        unique_classes = np.unique(classes)

        rgb_class = np.zeros((classes.shape[0], classes.shape[1], 3))

        colors = spectral.spy_colors

        for i in unique_classes:
            rgb_class[classes == i] = colors[i]

        rgb_class = np.asarray(rgb_class, np.uint8)

        plt.figure(figsize=figsize)
        plt.imshow(rgb_class)
        plt.title(title)
        plt.axis('off')
        plt.show()

# %%
model.load_weights(f"{DATASET}_SS_MixNet.keras")

Predicted_Class_Map = get_class_map(model, data, gt, window_size)

img_display(classes=Predicted_Class_Map, title='Predicted')
# Out:
# 100%|██████████| 749/749 [11:06<00:00,  1.12it/s]

# %%
model.save("SS_MixNet_ECA.keras")

from google.colab import files
files.download("SS_MixNet_ECA.keras")

# %%
model.save_weights("SS_MixNet_ECA_T4.weights.h5")

from google.colab import files
files.download("SS_MixNet_ECA_T4.weights.h5")

# %%
import numpy as np

np.save("X_test_idx.npy", X_test_idx)
np.save("y_test.npy", y_test)

from google.colab import files
files.download("X_test_idx.npy")
files.download("y_test.npy")
