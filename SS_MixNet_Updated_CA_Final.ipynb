# %%
# !pip install spectral tqdm scikit-learn

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Collecting spectral
#   Downloading spectral-0.24-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from spectral) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Downloading spectral-0.24-py3-none-any.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.0/249.0 kB 9.8 MB/s eta 0:00:00
# Installing collected packages: spectral
# Successfully installed spectral-0.24
# Mounted at /content/drive

# %%
import os
import numpy as np
import tensorflow as tf
from scipy.io import loadmat
from tqdm import tqdm
import matplotlib.pyplot as plt
import spectral

from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import minmax_scale
from sklearn.metrics import accuracy_score, confusion_matrix, cohen_kappa_score

from tensorflow.keras.layers import (
    Input, Conv3D, Conv2D, Dense, Dropout, Reshape,
    Concatenate, Add, Multiply,
    GlobalAveragePooling2D,
    Permute
)

from tensorflow.keras.models import Model

# %%
from tensorflow.keras import mixed_precision

mixed_precision.set_global_policy('mixed_float16')

print("Policy:", mixed_precision.global_policy())
# Out:
# Policy: <DTypePolicy "mixed_float16">

# %%
def loadData(name):

    data_path = '/content/drive/MyDrive/datasets'

    if name == 'Tangdaowan':
        data = loadmat(os.path.join(data_path, 'QUH-Tangdaowan.mat'))['Tangdaowan']
        labels = loadmat(os.path.join(data_path, 'QUH-Tangdaowan_GT.mat'))['TangdaowanGT']
        class_name = [
            "Rubber track","Flaggingv","Sandy","Asphalt","Boardwalk",
            "Rocky shallows","Grassland","Bulrush","Gravel road",
            "Ligustrum vicaryi","Coniferous pine","Spiraea","Bare soil",
            "Buxus sinica","Photinia serrulata","Populus",
            "Ulmus pumila L","Seawater"
        ]

    elif name == 'Qingyun':
        data = loadmat(os.path.join(data_path, 'QUH-Qingyun.mat'))['Chengqu']
        labels = loadmat(os.path.join(data_path, 'QUH-Qingyun_GT.mat'))['ChengquGT']
        class_name = [
            "Trees","Concrete building","Car",
            "Ironhide building","Plastic playground","Asphalt road"
        ]

    elif name == 'Pingan':
        data = loadmat(os.path.join(data_path, 'QUH-Pingan.mat'))['Haigang']
        labels = loadmat(os.path.join(data_path, 'QUH-Pingan_GT.mat'))['HaigangGT']
        class_name = [
            "Ship","Seawater","Trees","Concrete structure building",
            "Floating pier","Asphalt road","Brick houses",
            "Steel houses","Wharf construction land","Car","Road"
        ]

    return data, labels, class_name

# %%
def applyPCA(X, numComponents=15):

    newX = np.reshape(X, (-1, X.shape[2]))

    pca = PCA(n_components=numComponents)

    newX = pca.fit_transform(newX)

    newX = minmax_scale(newX, axis=1)

    newX = np.reshape(newX,(X.shape[0],X.shape[1],numComponents))

    return newX

# %%
def get_img_indexes(class_map, removeZeroindexes=True):

    if removeZeroindexes:
        indices = np.argwhere(class_map != 0)
    else:
        indices = np.argwhere(class_map != None)

    labels = class_map[indices[:,0], indices[:,1]]

    indices = [tuple(i) for i in indices]

    return indices, np.array(labels.tolist()) - 1

# %%
def splitTrainTestSet(X, y, testRatio):

    return train_test_split(
        X,
        y,
        test_size=testRatio,
        stratify=y,
        random_state=42
    )

# %%
def createImageCubes(X, indices, windowSize):

    margin = windowSize // 2

    N,M,P = X.shape

    X_padded = np.zeros((N+2*margin, M+2*margin, P))

    X_padded[margin:N+margin, margin:M+margin,:] = X

    patches=[]

    for idx in indices:

        i,j = idx

        i+=margin
        j+=margin

        patch = X_padded[i-margin:i+margin+1, j-margin:j+margin+1,:]

        patches.append(patch)

    patches=np.array(patches)

    patches = patches[...,np.newaxis]

    return patches

# %%
def spectral_mixer_block(x, hidden_dim, num_blocks=2):

    H,W,C,D = x.shape[1:]

    x = Permute((1,2,4,3))(x)

    x = Reshape((H*W, D, C))(x)

    for _ in range(num_blocks):

        x1 = Dense(hidden_dim, activation='gelu')(x)

        x1 = Dense(C)(x1)

        x = Add()([x,x1])

    return Reshape((H,W,C,D))(x)

# %%
def spatial_mixer_block(x, hidden_dim, num_blocks=2):

    H,W,C,D = x.shape[1:]

    x = Permute((3,4,1,2))(x)

    x = Reshape((C,D,H*W))(x)

    for _ in range(num_blocks):

        x1 = Dense(hidden_dim, activation='gelu')(x)

        x1 = Dense(H*W)(x1)

        x = Add()([x,x1])

    x = Permute((3,1,2))(x)

    return Reshape((H,W,C,D))(x)

# %%
from tensorflow.keras.layers import Lambda, Concatenate, Conv2D, Multiply

def coordinate_attention(x, reduction=32):

    H = x.shape[1]
    W = x.shape[2]
    C = x.shape[3]

    # Height pooling
    pool_h = Lambda(lambda z: tf.reduce_mean(z, axis=2, keepdims=True))(x)

    # Width pooling
    pool_w = Lambda(lambda z: tf.reduce_mean(z, axis=1, keepdims=True))(x)
    pool_w = Lambda(lambda z: tf.transpose(z, perm=[0,2,1,3]))(pool_w)

    y = Concatenate(axis=1)([pool_h, pool_w])

    mid_channels = max(8, C // reduction)

    y = Conv2D(mid_channels, 1, activation='gelu', padding='same')(y)

    # Split features
    x_h = Lambda(lambda z: z[:, :H, :, :])(y)
    x_w = Lambda(lambda z: z[:, H:, :, :])(y)

    x_w = Lambda(lambda z: tf.transpose(z, perm=[0,2,1,3]))(x_w)

    a_h = Conv2D(C, 1, activation='sigmoid', padding='same')(x_h)
    a_w = Conv2D(C, 1, activation='sigmoid', padding='same')(x_w)

    out = Multiply()([x, a_h])
    out = Multiply()([out, a_w])

    return out

# %%
def SS_MixNet(img_list, num_classes, mixer_dim=256):

    input_shape = img_list.shape[1:]

    inp = Input(shape=input_shape)

    x = Conv3D(32,(3,3,3),padding='same',activation='gelu')(inp)
    x = Conv3D(64,(3,3,3),padding='same',activation='gelu')(x)

    x_spe = spectral_mixer_block(x, mixer_dim)
    x_spa = spatial_mixer_block(x, mixer_dim)

    x = Concatenate(axis=4)([x_spe,x_spa])

    H,W,C,F = x.shape[1:]

    x = Reshape((H,W,C*F))(x)

    x = coordinate_attention(x)

    res = Conv2D(x.shape[-1],1,padding='same',activation='gelu')(x)

    x = Add()([x,res])

    x = GlobalAveragePooling2D()(x)

    x = Dropout(0.4)(x)

    out = Dense(num_classes,activation='softmax',dtype='float32')(x)

    model = Model(inp,out)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.05),
        metrics=['accuracy']
    )

    return model

# %%
DATASET='Tangdaowan'

data, gt, class_name = loadData(DATASET)

print(data.shape)
# Out:
# (1740, 860, 176)

# %%
data = applyPCA(data, numComponents=15)

# %%
indexes, labels = get_img_indexes(gt)

X_train_idx, X_test_idx, y_train, y_test = splitTrainTestSet(indexes,labels,0.95)

X_train_idx, X_val_idx, y_train, y_val = splitTrainTestSet(X_train_idx,y_train,0.30)

# %%
window_size=9

X_train = createImageCubes(data,X_train_idx,window_size)
X_val = createImageCubes(data,X_val_idx,window_size)

y_train = tf.keras.utils.to_categorical(y_train)
y_val = tf.keras.utils.to_categorical(y_val)

# %%
model = SS_MixNet(
    X_train,
    num_classes=len(class_name),
    mixer_dim=256
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 9, 9, 15,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d (Conv3D)     │ (None, 9, 9, 15,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3d_1 (Conv3D)   │ (None, 9, 9, 15,  │     55,360 │ conv3d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_1 (Permute) │ (None, 15, 64, 9, │          0 │ conv3d_1[0][0]    │
# │                     │ 9)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute (Permute)   │ (None, 9, 9, 64,  │          0 │ conv3d_1[0][0]    │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 15, 64,    │          0 │ permute_1[0][0]   │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 81, 64,    │          0 │ permute[0][0]     │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 15, 64,    │     20,992 │ reshape_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 81, 64,    │      4,096 │ reshape[0][0]     │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 15, 64,    │     20,817 │ dense_4[0][0]     │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 81, 64,    │      3,855 │ dense[0][0]       │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 15, 64,    │          0 │ reshape_2[0][0],  │
# │                     │ 81)               │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 81, 64,    │          0 │ reshape[0][0],    │
# │                     │ 15)               │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 15, 64,    │     20,992 │ add_2[0][0]       │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 81, 64,    │      4,096 │ add[0][0]         │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 15, 64,    │     20,817 │ dense_6[0][0]     │
# │                     │ 81)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 81, 64,    │      3,855 │ dense_2[0][0]     │
# │                     │ 15)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 15, 64,    │          0 │ add_2[0][0],      │
# │                     │ 81)               │            │ dense_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 81, 64,    │          0 │ add[0][0],        │
# │                     │ 15)               │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ permute_2 (Permute) │ (None, 81, 15,    │          0 │ add_3[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 9, 9, 15,  │          0 │ add_1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 9, 9, 15,  │          0 │ permute_2[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 9, 9, 15,  │          0 │ reshape_1[0][0],  │
# │ (Concatenate)       │ 128)              │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 9, 9,      │          0 │ concatenate[0][0] │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 1, 9,      │          0 │ reshape_4[0][0]   │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 9, 1,      │          0 │ reshape_4[0][0]   │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, 9, 1,      │          0 │ lambda_1[0][0]    │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 18, 1,     │          0 │ lambda[0][0],     │
# │ (Concatenate)       │ 1920)             │            │ lambda_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 18, 1, 60) │    115,260 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_3 (Lambda)   │ (None, 9, 1, 60)  │          0 │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_4 (Lambda)   │ (None, 9, 1, 60)  │          0 │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 9, 1,      │    117,120 │ lambda_3[0][0]    │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_5 (Lambda)   │ (None, 1, 9, 60)  │          0 │ lambda_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 9, 9,      │          0 │ reshape_4[0][0],  │
# │                     │ 1920)             │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 1, 9,      │    117,120 │ lambda_5[0][0]    │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 9, 9,      │          0 │ multiply[0][0],   │
# │ (Multiply)          │ 1920)             │            │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 9, 9,      │  3,688,320 │ multiply_1[0][0]  │
# │                     │ 1920)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 9, 9,      │          0 │ multiply_1[0][0], │
# │                     │ 1920)             │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 1920)      │          0 │ add_4[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 1920)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 18)        │     34,578 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,228,174 (16.13 MB)
#  Trainable params: 4,228,174 (16.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    f"{DATASET}_SS_MixNet_CA.keras",
    monitor='val_accuracy',
    save_best_only=True,
    verbose=1
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.5,
    patience=8,
    min_lr=5e-5
)

history = model.fit(
    X_train,
    y_train,
    epochs=60,
    batch_size=256,
    validation_data=(X_val,y_val),
    callbacks=[checkpoint, lr_callback]
)
# Out:
# Epoch 1/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.3460 - loss: 2.3231
# Epoch 1: val_accuracy improved from None to 0.69968, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 1: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 87s 554ms/step - accuracy: 0.4717 - loss: 1.8902 - val_accuracy: 0.6997 - val_loss: 1.2604 - learning_rate: 3.0000e-04
# Epoch 2/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7172 - loss: 1.1216
# Epoch 2: val_accuracy improved from 0.69968 to 0.81390, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 2: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 19s 243ms/step - accuracy: 0.7546 - loss: 1.0125 - val_accuracy: 0.8139 - val_loss: 0.8506 - learning_rate: 3.0000e-04
# Epoch 3/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.8083 - loss: 0.8532
# Epoch 3: val_accuracy improved from 0.81390 to 0.84966, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 3: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 256ms/step - accuracy: 0.8259 - loss: 0.8097 - val_accuracy: 0.8497 - val_loss: 0.7411 - learning_rate: 3.0000e-04
# Epoch 4/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.8579 - loss: 0.7220
# Epoch 4: val_accuracy improved from 0.84966 to 0.89367, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 4: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 22s 281ms/step - accuracy: 0.8716 - loss: 0.6972 - val_accuracy: 0.8937 - val_loss: 0.6305 - learning_rate: 3.0000e-04
# Epoch 5/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.8918 - loss: 0.6398
# Epoch 5: val_accuracy improved from 0.89367 to 0.91377, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 5: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 22s 287ms/step - accuracy: 0.9007 - loss: 0.6221 - val_accuracy: 0.9138 - val_loss: 0.5771 - learning_rate: 3.0000e-04
# Epoch 6/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9192 - loss: 0.5777
# Epoch 6: val_accuracy improved from 0.91377 to 0.92776, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 6: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 266ms/step - accuracy: 0.9212 - loss: 0.5664 - val_accuracy: 0.9278 - val_loss: 0.5369 - learning_rate: 3.0000e-04
# Epoch 7/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.9281 - loss: 0.5423
# Epoch 7: val_accuracy improved from 0.92776 to 0.94175, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 7: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 263ms/step - accuracy: 0.9311 - loss: 0.5355 - val_accuracy: 0.9418 - val_loss: 0.5074 - learning_rate: 3.0000e-04
# Epoch 8/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9426 - loss: 0.5146
# Epoch 8: val_accuracy did not improve from 0.94175
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 265ms/step - accuracy: 0.9426 - loss: 0.5102 - val_accuracy: 0.9410 - val_loss: 0.4989 - learning_rate: 3.0000e-04
# Epoch 9/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9474 - loss: 0.4914
# Epoch 9: val_accuracy improved from 0.94175 to 0.95252, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 9: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 274ms/step - accuracy: 0.9471 - loss: 0.4932 - val_accuracy: 0.9525 - val_loss: 0.4740 - learning_rate: 3.0000e-04
# Epoch 10/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9557 - loss: 0.4715
# Epoch 10: val_accuracy improved from 0.95252 to 0.95431, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 10: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 269ms/step - accuracy: 0.9529 - loss: 0.4752 - val_accuracy: 0.9543 - val_loss: 0.4667 - learning_rate: 3.0000e-04
# Epoch 11/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9576 - loss: 0.4675
# Epoch 11: val_accuracy improved from 0.95431 to 0.95658, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 11: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 269ms/step - accuracy: 0.9582 - loss: 0.4636 - val_accuracy: 0.9566 - val_loss: 0.4561 - learning_rate: 3.0000e-04
# Epoch 12/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.9604 - loss: 0.4570
# Epoch 12: val_accuracy improved from 0.95658 to 0.96125, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 12: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 268ms/step - accuracy: 0.9626 - loss: 0.4501 - val_accuracy: 0.9612 - val_loss: 0.4472 - learning_rate: 3.0000e-04
# Epoch 13/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9617 - loss: 0.4481
# Epoch 13: val_accuracy improved from 0.96125 to 0.96292, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 13: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 23s 294ms/step - accuracy: 0.9634 - loss: 0.4436 - val_accuracy: 0.9629 - val_loss: 0.4367 - learning_rate: 3.0000e-04
# Epoch 14/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9651 - loss: 0.4365
# Epoch 14: val_accuracy improved from 0.96292 to 0.96615, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 14: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 272ms/step - accuracy: 0.9675 - loss: 0.4340 - val_accuracy: 0.9662 - val_loss: 0.4289 - learning_rate: 3.0000e-04
# Epoch 15/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9735 - loss: 0.4215
# Epoch 15: val_accuracy did not improve from 0.96615
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 256ms/step - accuracy: 0.9726 - loss: 0.4235 - val_accuracy: 0.9653 - val_loss: 0.4324 - learning_rate: 3.0000e-04
# Epoch 16/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.9747 - loss: 0.4156
# Epoch 16: val_accuracy improved from 0.96615 to 0.97022, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 16: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 267ms/step - accuracy: 0.9739 - loss: 0.4173 - val_accuracy: 0.9702 - val_loss: 0.4199 - learning_rate: 3.0000e-04
# Epoch 17/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9751 - loss: 0.4126
# Epoch 17: val_accuracy improved from 0.97022 to 0.97381, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 17: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 273ms/step - accuracy: 0.9756 - loss: 0.4125 - val_accuracy: 0.9738 - val_loss: 0.4140 - learning_rate: 3.0000e-04
# Epoch 18/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9765 - loss: 0.4088
# Epoch 18: val_accuracy did not improve from 0.97381
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 265ms/step - accuracy: 0.9764 - loss: 0.4099 - val_accuracy: 0.9730 - val_loss: 0.4099 - learning_rate: 3.0000e-04
# Epoch 19/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9787 - loss: 0.4039
# Epoch 19: val_accuracy improved from 0.97381 to 0.97596, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 19: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 270ms/step - accuracy: 0.9789 - loss: 0.4034 - val_accuracy: 0.9760 - val_loss: 0.4043 - learning_rate: 3.0000e-04
# Epoch 20/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9810 - loss: 0.3975
# Epoch 20: val_accuracy did not improve from 0.97596
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 264ms/step - accuracy: 0.9801 - loss: 0.3989 - val_accuracy: 0.9740 - val_loss: 0.4073 - learning_rate: 3.0000e-04
# Epoch 21/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9837 - loss: 0.3920
# Epoch 21: val_accuracy improved from 0.97596 to 0.97656, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 21: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 270ms/step - accuracy: 0.9819 - loss: 0.3946 - val_accuracy: 0.9766 - val_loss: 0.4002 - learning_rate: 3.0000e-04
# Epoch 22/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9827 - loss: 0.3904
# Epoch 22: val_accuracy improved from 0.97656 to 0.97716, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 22: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 270ms/step - accuracy: 0.9827 - loss: 0.3914 - val_accuracy: 0.9772 - val_loss: 0.4000 - learning_rate: 3.0000e-04
# Epoch 23/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9835 - loss: 0.3899
# Epoch 23: val_accuracy improved from 0.97716 to 0.97740, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 23: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 268ms/step - accuracy: 0.9836 - loss: 0.3903 - val_accuracy: 0.9774 - val_loss: 0.4001 - learning_rate: 3.0000e-04
# Epoch 24/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9860 - loss: 0.3836
# Epoch 24: val_accuracy improved from 0.97740 to 0.97955, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 24: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 269ms/step - accuracy: 0.9863 - loss: 0.3844 - val_accuracy: 0.9795 - val_loss: 0.3914 - learning_rate: 3.0000e-04
# Epoch 25/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9871 - loss: 0.3804
# Epoch 25: val_accuracy did not improve from 0.97955
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 263ms/step - accuracy: 0.9862 - loss: 0.3813 - val_accuracy: 0.9786 - val_loss: 0.3925 - learning_rate: 3.0000e-04
# Epoch 26/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9878 - loss: 0.3797
# Epoch 26: val_accuracy improved from 0.97955 to 0.97967, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 26: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 270ms/step - accuracy: 0.9872 - loss: 0.3796 - val_accuracy: 0.9797 - val_loss: 0.3881 - learning_rate: 3.0000e-04
# Epoch 27/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9867 - loss: 0.3788
# Epoch 27: val_accuracy improved from 0.97967 to 0.98074, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 27: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 273ms/step - accuracy: 0.9868 - loss: 0.3786 - val_accuracy: 0.9807 - val_loss: 0.3873 - learning_rate: 3.0000e-04
# Epoch 28/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9891 - loss: 0.3759
# Epoch 28: val_accuracy improved from 0.98074 to 0.98134, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 28: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 41s 272ms/step - accuracy: 0.9882 - loss: 0.3762 - val_accuracy: 0.9813 - val_loss: 0.3887 - learning_rate: 3.0000e-04
# Epoch 29/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.9888 - loss: 0.3776
# Epoch 29: val_accuracy did not improve from 0.98134
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 42s 289ms/step - accuracy: 0.9889 - loss: 0.3756 - val_accuracy: 0.9811 - val_loss: 0.3868 - learning_rate: 3.0000e-04
# Epoch 30/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.9897 - loss: 0.3708
# Epoch 30: val_accuracy improved from 0.98134 to 0.98194, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 30: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 278ms/step - accuracy: 0.9900 - loss: 0.3709 - val_accuracy: 0.9819 - val_loss: 0.3819 - learning_rate: 3.0000e-04
# Epoch 31/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.9908 - loss: 0.3705
# Epoch 31: val_accuracy did not improve from 0.98194
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 255ms/step - accuracy: 0.9913 - loss: 0.3692 - val_accuracy: 0.9813 - val_loss: 0.3818 - learning_rate: 3.0000e-04
# Epoch 32/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.9913 - loss: 0.3691
# Epoch 32: val_accuracy did not improve from 0.98194
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 256ms/step - accuracy: 0.9918 - loss: 0.3681 - val_accuracy: 0.9818 - val_loss: 0.3849 - learning_rate: 3.0000e-04
# Epoch 33/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9920 - loss: 0.3641
# Epoch 33: val_accuracy improved from 0.98194 to 0.98314, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 33: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 275ms/step - accuracy: 0.9916 - loss: 0.3652 - val_accuracy: 0.9831 - val_loss: 0.3778 - learning_rate: 3.0000e-04
# Epoch 34/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9915 - loss: 0.3661
# Epoch 34: val_accuracy improved from 0.98314 to 0.98517, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 34: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 273ms/step - accuracy: 0.9921 - loss: 0.3650 - val_accuracy: 0.9852 - val_loss: 0.3800 - learning_rate: 3.0000e-04
# Epoch 35/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9952 - loss: 0.3601
# Epoch 35: val_accuracy did not improve from 0.98517
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 263ms/step - accuracy: 0.9937 - loss: 0.3613 - val_accuracy: 0.9842 - val_loss: 0.3782 - learning_rate: 3.0000e-04
# Epoch 36/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9949 - loss: 0.3578
# Epoch 36: val_accuracy did not improve from 0.98517
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 262ms/step - accuracy: 0.9939 - loss: 0.3594 - val_accuracy: 0.9818 - val_loss: 0.3842 - learning_rate: 3.0000e-04
# Epoch 37/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9956 - loss: 0.3597
# Epoch 37: val_accuracy improved from 0.98517 to 0.98553, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 37: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 270ms/step - accuracy: 0.9945 - loss: 0.3597 - val_accuracy: 0.9855 - val_loss: 0.3782 - learning_rate: 3.0000e-04
# Epoch 38/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9939 - loss: 0.3602
# Epoch 38: val_accuracy did not improve from 0.98553
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 265ms/step - accuracy: 0.9941 - loss: 0.3594 - val_accuracy: 0.9845 - val_loss: 0.3756 - learning_rate: 3.0000e-04
# Epoch 39/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9942 - loss: 0.3571
# Epoch 39: val_accuracy did not improve from 0.98553
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 267ms/step - accuracy: 0.9943 - loss: 0.3578 - val_accuracy: 0.9850 - val_loss: 0.3753 - learning_rate: 3.0000e-04
# Epoch 40/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9956 - loss: 0.3551
# Epoch 40: val_accuracy did not improve from 0.98553
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 266ms/step - accuracy: 0.9951 - loss: 0.3562 - val_accuracy: 0.9841 - val_loss: 0.3738 - learning_rate: 3.0000e-04
# Epoch 41/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9958 - loss: 0.3539
# Epoch 41: val_accuracy did not improve from 0.98553
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 267ms/step - accuracy: 0.9949 - loss: 0.3562 - val_accuracy: 0.9848 - val_loss: 0.3762 - learning_rate: 3.0000e-04
# Epoch 42/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9946 - loss: 0.3566
# Epoch 42: val_accuracy improved from 0.98553 to 0.98565, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 42: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 271ms/step - accuracy: 0.9945 - loss: 0.3560 - val_accuracy: 0.9856 - val_loss: 0.3735 - learning_rate: 3.0000e-04
# Epoch 43/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9948 - loss: 0.3539
# Epoch 43: val_accuracy improved from 0.98565 to 0.98720, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 43: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 270ms/step - accuracy: 0.9951 - loss: 0.3539 - val_accuracy: 0.9872 - val_loss: 0.3707 - learning_rate: 3.0000e-04
# Epoch 44/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9970 - loss: 0.3498
# Epoch 44: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 263ms/step - accuracy: 0.9962 - loss: 0.3524 - val_accuracy: 0.9847 - val_loss: 0.3752 - learning_rate: 3.0000e-04
# Epoch 45/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9961 - loss: 0.3525
# Epoch 45: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 263ms/step - accuracy: 0.9959 - loss: 0.3526 - val_accuracy: 0.9852 - val_loss: 0.3726 - learning_rate: 3.0000e-04
# Epoch 46/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9969 - loss: 0.3495
# Epoch 46: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 263ms/step - accuracy: 0.9968 - loss: 0.3494 - val_accuracy: 0.9848 - val_loss: 0.3721 - learning_rate: 3.0000e-04
# Epoch 47/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9973 - loss: 0.3491
# Epoch 47: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 263ms/step - accuracy: 0.9969 - loss: 0.3497 - val_accuracy: 0.9858 - val_loss: 0.3712 - learning_rate: 3.0000e-04
# Epoch 48/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9967 - loss: 0.3494
# Epoch 48: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 262ms/step - accuracy: 0.9963 - loss: 0.3496 - val_accuracy: 0.9867 - val_loss: 0.3710 - learning_rate: 3.0000e-04
# Epoch 49/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9957 - loss: 0.3511
# Epoch 49: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 263ms/step - accuracy: 0.9960 - loss: 0.3508 - val_accuracy: 0.9861 - val_loss: 0.3746 - learning_rate: 3.0000e-04
# Epoch 50/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9968 - loss: 0.3498
# Epoch 50: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 263ms/step - accuracy: 0.9970 - loss: 0.3490 - val_accuracy: 0.9860 - val_loss: 0.3720 - learning_rate: 3.0000e-04
# Epoch 51/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9964 - loss: 0.3498
# Epoch 51: val_accuracy did not improve from 0.98720
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 264ms/step - accuracy: 0.9969 - loss: 0.3485 - val_accuracy: 0.9866 - val_loss: 0.3684 - learning_rate: 3.0000e-04
# Epoch 52/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9980 - loss: 0.3450
# Epoch 52: val_accuracy improved from 0.98720 to 0.98756, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 52: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 269ms/step - accuracy: 0.9983 - loss: 0.3439 - val_accuracy: 0.9876 - val_loss: 0.3667 - learning_rate: 1.5000e-04
# Epoch 53/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9986 - loss: 0.3430
# Epoch 53: val_accuracy improved from 0.98756 to 0.98804, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 53: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 270ms/step - accuracy: 0.9986 - loss: 0.3425 - val_accuracy: 0.9880 - val_loss: 0.3656 - learning_rate: 1.5000e-04
# Epoch 54/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9985 - loss: 0.3422
# Epoch 54: val_accuracy did not improve from 0.98804
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 264ms/step - accuracy: 0.9986 - loss: 0.3422 - val_accuracy: 0.9878 - val_loss: 0.3661 - learning_rate: 1.5000e-04
# Epoch 55/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9983 - loss: 0.3418
# Epoch 55: val_accuracy did not improve from 0.98804
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 266ms/step - accuracy: 0.9985 - loss: 0.3418 - val_accuracy: 0.9880 - val_loss: 0.3656 - learning_rate: 1.5000e-04
# Epoch 56/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9989 - loss: 0.3411
# Epoch 56: val_accuracy did not improve from 0.98804
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 266ms/step - accuracy: 0.9987 - loss: 0.3417 - val_accuracy: 0.9876 - val_loss: 0.3662 - learning_rate: 1.5000e-04
# Epoch 57/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9983 - loss: 0.3420
# Epoch 57: val_accuracy improved from 0.98804 to 0.98828, saving model to Tangdaowan_SS_MixNet_CA.keras
#
# Epoch 57: finished saving model to Tangdaowan_SS_MixNet_CA.keras
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 272ms/step - accuracy: 0.9987 - loss: 0.3415 - val_accuracy: 0.9883 - val_loss: 0.3652 - learning_rate: 1.5000e-04
# Epoch 58/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9984 - loss: 0.3412
# Epoch 58: val_accuracy did not improve from 0.98828
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 266ms/step - accuracy: 0.9987 - loss: 0.3411 - val_accuracy: 0.9878 - val_loss: 0.3656 - learning_rate: 1.5000e-04
# Epoch 59/60
# 76/77 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.9995 - loss: 0.3398
# Epoch 59: val_accuracy did not improve from 0.98828
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 20s 267ms/step - accuracy: 0.9989 - loss: 0.3407 - val_accuracy: 0.9877 - val_loss: 0.3656 - learning_rate: 1.5000e-04
# Epoch 60/60
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9989 - loss: 0.3405
# Epoch 60: val_accuracy did not improve from 0.98828
# 77/77 ━━━━━━━━━━━━━━━━━━━━ 21s 269ms/step - accuracy: 0.9993 - loss: 0.3402 - val_accuracy: 0.9876 - val_loss: 0.3652 - learning_rate: 1.5000e-04

# %%
import pickle

with open("training_history.pkl", "wb") as f:
    pickle.dump(history.history, f)

print("Training history saved.")
# Out:
# Training history saved.

# %%
from google.colab import files

files.download("training_history.pkl")

# %%
import numpy as np

np.save("training_history.npy", history.history)

print("Training history saved as training_history.npy")
# Out:
# Training history saved as training_history.npy

# %%
from google.colab import files
files.download("training_history.npy")

# %%
import seaborn as sns

# %%
plt.figure(figsize=(7,5))

plt.plot(history.history['loss'], label="Train Loss")
plt.plot(history.history['val_loss'], label="Validation Loss")

plt.title("Epoch vs Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.legend()
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(7,5))

plt.plot(history.history['accuracy'], label="Train Accuracy")
plt.plot(history.history['val_accuracy'], label="Validation Accuracy")

plt.title("Epoch vs Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")

plt.legend()
plt.grid(True)

plt.show()

# %%
def predict_by_batching(model, idx, batch_size, X, windowSize):

    preds=[]

    for i in tqdm(range(0,len(idx),batch_size)):

        batch = createImageCubes(X,idx[i:i+batch_size],windowSize)

        preds.append(model.predict(batch,verbose=0))

    return np.concatenate(preds)

# %%
Y_pred_test = predict_by_batching(model,X_test_idx,2000,data,window_size)

y_pred_test = np.argmax(Y_pred_test,axis=1)

oa = accuracy_score(y_test,y_pred_test)
kappa = cohen_kappa_score(y_test,y_pred_test)

cm = confusion_matrix(y_test,y_pred_test)

plt.figure(figsize=(8,6))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.title("Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")

plt.show()

class_acc = cm.diagonal()/cm.sum(axis=1)
aa = np.mean(class_acc)

print("Overall Accuracy:",round(oa*100,2))
print("Average Accuracy:",round(aa*100,2))
print("Kappa:",round(kappa*100,2))
# Out:
# 100%|██████████| 265/265 [04:15<00:00,  1.04it/s]
# Overall Accuracy: 98.65
# Average Accuracy: 97.57
# Kappa: 98.46

# %%
import json

test_metrics = {
    "Overall Accuracy (OA)": float(oa),
    "Average Accuracy (AA)": float(aa),
    "Kappa Score": float(kappa)
}

with open("test_metrics.json", "w") as f:
    json.dump(test_metrics, f, indent=4)

print("Test metrics saved.")
# Out:
# Test metrics saved.

# %%
from google.colab import files

files.download("test_metrics.json")

# %%
import pandas as pd

cm_df = pd.DataFrame(cm, index=class_name, columns=class_name)

cm_df.to_csv("confusion_matrix_test.csv")

print("Confusion matrix saved.")
# Out:
# Confusion matrix saved.

# %%
from google.colab import files

files.download("confusion_matrix_test.csv")

# %%
from sklearn.metrics import classification_report

# %%
print("\nClassification Report:\n")

print(
    classification_report(
        y_test,
        y_pred_test,
        target_names=class_name,
        digits=4
    )
)
# Out:
# Classification Report:
#
#                     precision    recall  f1-score   support
#
#       Rubber track     0.9980    0.9985    0.9982     24557
#          Flaggingv     0.9941    0.9969    0.9955     52775
#              Sandy     0.9746    0.9845    0.9796     32335
#            Asphalt     0.9974    0.9973    0.9973     57655
#          Boardwalk     0.9994    0.9864    0.9929      1769
#     Rocky shallows     0.9812    0.9783    0.9797     35269
#          Grassland     0.9333    0.9119    0.9225     13421
#            Bulrush     0.9996    0.9997    0.9996     60883
#        Gravel road     0.9978    0.9968    0.9973     29160
#  Ligustrum vicaryi     0.9963    0.9416    0.9681      1694
#    Coniferous pine     0.9723    0.9563    0.9642     20174
#            Spiraea     0.9742    0.9564    0.9652       711
#          Bare soil     0.9981    0.9994    0.9988      1602
#       Buxus sinica     0.9707    0.9846    0.9776       842
# Photinia serrulata     0.9706    0.9383    0.9542     13319
#            Populus     0.9769    0.9860    0.9814    133859
#     Ulmus pumila L     0.9940    0.9491    0.9710      9312
#           Seawater     0.9995    1.0000    0.9997     40161
#
#           accuracy                         0.9865    529498
#          macro avg     0.9849    0.9757    0.9802    529498
#       weighted avg     0.9865    0.9865    0.9865    529498

# %%
import pandas as pd

report = classification_report(
    y_test,
    y_pred_test,
    target_names=class_name,
    output_dict=True
)

df_report = pd.DataFrame(report).transpose()

df_report.to_csv("classification_report.csv")

pd.DataFrame(cm).to_csv("confusion_matrix.csv")

print("Results saved.")
# Out:
# Results saved.

# %%
import pandas as pd

report_df = pd.DataFrame(report).transpose()

report_df.to_csv("classification_report.csv")

print("Classification report saved.")
# Out:
# Classification report saved.

# %%
from google.colab import files

files.download("classification_report.csv")

# %%
import pandas as pd
import numpy as np

# -----------------------------
# Compute per-class accuracy
# -----------------------------
class_accuracy = cm.diagonal() / cm.sum(axis=1) * 100

rows = []

for i in range(len(class_name)):

    train_count = (y_train.argmax(axis=1) == i).sum()
    val_count   = (y_val.argmax(axis=1) == i).sum()
    test_count  = (y_test == i).sum()
    total_count = (gt == (i+1)).sum()

    rows.append([
        class_name[i],
        train_count,
        val_count,
        test_count,
        total_count,
        round(class_accuracy[i], 2)
    ])

# -----------------------------
# Create DataFrame
# -----------------------------
df = pd.DataFrame(
    rows,
    columns=[
        "Class",
        "Train",
        "Val",
        "Test",
        "Total",
        "SS-MixNet (%)"
    ]
)

# -----------------------------
# Summary Metrics
# -----------------------------
summary_rows = pd.DataFrame([
    ["OA (%)", "", "", "", "", round(oa * 100, 2)],
    ["AA (%)", "", "", "", "", round(aa * 100, 2)],
    ["Kappa (×100)", "", "", "", "", round(kappa * 100, 2)]
], columns=df.columns)

df_final = pd.concat([df, summary_rows], ignore_index=True)

# -----------------------------
# Pretty Print Table
# -----------------------------
print("\n")
print("=" * 90)
print(f"{'Classification Performance of SS-MixNet on ' + DATASET:^90}")
print("=" * 90)

print(f"{'Class':<25}{'Train':>8}{'Val':>8}{'Test':>10}{'Total':>10}{'Accuracy (%)':>15}")
print("-" * 90)

for i in range(len(class_name)):
    print(f"{df.iloc[i,0]:<25}"
          f"{df.iloc[i,1]:>8}"
          f"{df.iloc[i,2]:>8}"
          f"{df.iloc[i,3]:>10}"
          f"{df.iloc[i,4]:>10}"
          f"{df.iloc[i,5]:>15}")

print("-" * 90)

print(f"{'Overall Accuracy (OA)':<25}{'':>8}{'':>8}{'':>10}{'':>10}{round(oa*100,2):>15}")
print(f"{'Average Accuracy (AA)':<25}{'':>8}{'':>8}{'':>10}{'':>10}{round(aa*100,2):>15}")
print(f"{'Kappa (×100)':<25}{'':>8}{'':>8}{'':>10}{'':>10}{round(kappa*100,2):>15}")

print("=" * 90)
# Out:
# ==========================================================================================
#                   Classification Performance of SS-MixNet on Tangdaowan
# ==========================================================================================
# Class                       Train     Val      Test     Total   Accuracy (%)
# ------------------------------------------------------------------------------------------
# Rubber track                  904     388     24557     25849          99.85
# Flaggingv                    1945     833     52775     55553          99.69
# Sandy                        1191     511     32335     34037          98.45
# Asphalt                      2124     911     57655     60690          99.73
# Boardwalk                      65      28      1769      1862          98.64
# Rocky shallows               1299     557     35269     37125          97.83
# Grassland                     494     212     13421     14127          91.19
# Bulrush                      2243     961     60883     64087          99.97
# Gravel road                  1075     460     29160     30695          99.68
# Ligustrum vicaryi              62      27      1694      1783          94.16
# Coniferous pine               743     319     20174     21236          95.63
# Spiraea                        27      11       711       749          95.64
# Bare soil                      59      25      1602      1686          99.94
# Buxus sinica                   31      13       842       886          98.46
# Photinia serrulata            491     210     13319     14020          93.83
# Populus                      4931    2114    133859    140904           98.6
# Ulmus pumila L                343     147      9312      9802          94.91
# Seawater                     1480     634     40161     42275          100.0
# ------------------------------------------------------------------------------------------
# Overall Accuracy (OA)                                                  98.65
# Average Accuracy (AA)                                                  97.57
# Kappa (×100)                                                           98.46
# ==========================================================================================

# %%
def get_class_map(model, X, label, window_size):

    indexes = np.argwhere(label != None)

    indexes = [tuple(i) for i in indexes]

    preds = []

    for i in tqdm(range(0, len(indexes), 2000)):
        batch_idx = indexes[i:i+2000]

        patches = createImageCubes(X, batch_idx, window_size)

        y_pred = model.predict(patches, verbose=0)

        preds.append(y_pred)

    preds = np.concatenate(preds)

    preds = np.argmax(preds, axis=1)

    Predicted_Class_Map = np.reshape(preds, label.shape)

    return Predicted_Class_Map

# %%
def img_display(data=None, rgb_band=None, classes=None, title=None, figsize=(7,7)):

    if data is not None:
        im_rgb = data[:,:,rgb_band]
        im_rgb = im_rgb / np.max(im_rgb) * 255
        im_rgb = np.asarray(im_rgb, np.uint8)

        plt.figure(figsize=figsize)
        plt.imshow(im_rgb)
        plt.title(title)
        plt.axis('off')
        plt.show()

    elif classes is not None:

        unique_classes = np.unique(classes)

        rgb_class = np.zeros((classes.shape[0], classes.shape[1], 3))

        colors = spectral.spy_colors

        for i in unique_classes:
            rgb_class[classes == i] = colors[i]

        rgb_class = np.asarray(rgb_class, np.uint8)

        plt.figure(figsize=figsize)
        plt.imshow(rgb_class)
        plt.title(title)
        plt.axis('off')
        plt.show()

# %%
model.load_weights(f"{DATASET}_SS_MixNet_CA.keras")

Predicted_Class_Map = get_class_map(model, data, gt, window_size)

img_display(classes=Predicted_Class_Map, title='Predicted')
# Out:
# 100%|██████████| 749/749 [11:17<00:00,  1.11it/s]

# %%
model.save("SS_MixNet_CA.keras")

from google.colab import files
files.download("SS_MixNet_CA.keras")

# %%
model.save_weights("SS_MixNet_CA_T4.weights.h5")

from google.colab import files
files.download("SS_MixNet_CA_T4.weights.h5")

# %%
import numpy as np

np.save("X_test_idx.npy", X_test_idx)
np.save("y_test.npy", y_test)

from google.colab import files
files.download("X_test_idx.npy")
files.download("y_test.npy")
